# %%
# %pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (1.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import os
import json
import dotenv

# %%
dotenv=dotenv.load_dotenv()

# %% [markdown]
# #**The Lord Of the Rings**

# %%
url = "https://the-one-api.dev/v2/movie"

One_API_KEY=os.getenv("One_API_KEY")

headers = {
  "Authorization": One_API_KEY
}

response = requests.request("GET", url, headers=headers)
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'docs': [{'_id': '5cd95395de30eff6ebccde56',
#    'name': 'The Lord of the Rings Series',
#    'runtimeInMinutes': 558,
#    'budgetInMillions': 281,
#    'boxOfficeRevenueInMillions': 2917,
#    'academyAwardNominations': 30,
#    'academyAwardWins': 17,
#    'rottenTomatoesScore': 94},
#   {'_id': '5cd95395de30eff6ebccde57',
#    'name': 'The Hobbit Series',
#    'runtimeInMinutes': 462,
#    'budgetInMillions': 675,
#    'boxOfficeRevenueInMillions': 2932,
#    'academyAwardNominations': 7,
#    'academyAwardWins': 1,
#    'rottenTomatoesScore': 66.33333333},
#   {'_id': '5cd95395de30eff6ebccde58',
#    'name': 'The Unexpected Journey',
#    'runtimeInMinutes': 169,
#    'budgetInMillions': 200,
#    'boxOfficeRevenueInMillions': 1021,
#    'academyAwardNominations': 3,
#    'academyAwardWins': 1,
#    'rottenTomatoesScore': 64},
#   {'_id': '5cd95395de30eff6ebccde59',
#    'name': 'The Desolation of Smaug',
#    'runtimeInMinutes': 161,
#    'budgetInMillions': 217,
#    'boxOfficeRevenueInMillions': 958.4,
#    'academyAwardNominations': 3,
#    'academyAwardWins': 0,
#    'rottenTomatoesScore': 75},
#   {'_id': '5cd95395de30eff6ebccde5a',
#    'name': 'The Battle of the Five Armies',
#    'runtimeInMinutes': 144,
#    'budgetInMillions': 250,
#    'boxOfficeRevenueInMillions': 956,
#    'academyAwardNominations': 1,
#    'academyAwardWins': 0,
#    'rottenTomatoesScore': 60},
#   {'_id': '5cd95395de30eff6ebccde5b',
#    'name': 'The Two Towers',
#    'runtimeInMinutes': 179,
#    'budgetInMillions': 94,
#    'boxOfficeRevenueInMillions': 926,
#    'academyAwardNominations': 6,
#    'academyAwardWins': 2,
#    'rottenTomatoesScore': 96},
#   {'_id': '5cd95395de30eff6ebccde5c',
#    'name': 'The Fellowship of the Ring',
#    'runtimeInMinutes': 178,
#    'budgetInMillions': 93,
#    'boxOfficeRevenueInMillions': 871.5,
#    'academyAwardNominations': 13,
#    'academyAwardWins': 4,
#    'rottenTomatoesScore': 91},
#   {'_id': '5cd95395de30eff6ebccde5d',
#    'name': 'The Return of the King',
#    'runtimeInMinutes': 201,
#    'budgetInMillions': 94,
#    'boxOfficeRevenueInMillions': 1120,
#    'academyAwardNominations': 11,
#    'academyAwardWins': 11,
#    'rottenTomatoesScore': 95}],
#  'total': 8,
#  'limit': 1000,
#  'offset': 0,
#  'page': 1,
#  'pages': 1}

# %% [markdown]
# #**Icon finder**

# %%
import requests

url = "https://api.iconfinder.com/v4/icons/search?query=arrow&count=10"

IconFinder_API_KEY=os.getenv("IconFinder_API_KEY")

headers = {
    "accept": "application/json",
    "Authorization": IconFinder_API_KEY
}

response = requests.get(url, headers=headers)

response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'total_count': 189464,
#  'icons': [{'icon_id': 4470662,
#    'tags': ['app', 'back', 'mobile', 'ui', 'ux', 'web', 'arrow'],
#    'published_at': '2019-04-05T08:53:39.350522',
#    'is_premium': False,
#    'type': 'vector',
#    'containers': [],
#    'raster_sizes': [{'formats': [{'format': 'png',
#        'preview_url': 'https://cdn0.iconfinder.com/data/icons/uiux-001-line/32/UI_UX_UIUX_Back-16.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4470662/formats/png/16/download'}],
#      'size': 16,
#      'size_width': 16,
#      'size_height': 16},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn0.iconfinder.com/data/icons/uiux-001-line/32/UI_UX_UIUX_Back-20.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4470662/formats/png/20/download'}],
#      'size': 20,
#      'size_width': 20,
#      'size_height': 20},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn0.iconfinder.com/data/icons/uiux-001-line/32/UI_UX_UIUX_Back-24.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4470662/formats/png/24/download'}],
#      'size': 24,
#      'size_width': 24,
#      'size_height': 24},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn0.iconfinder.com/data/icons/uiux-001-line/32/UI_UX_UIUX_Back-32.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4470662/formats/png/32/download'}],
#      'size': 32,
#      'size_width': 32,
#      'size_height': 32},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn0.iconfinder.com/data/icons/uiux-001-line/32/UI_UX_UIUX_Back-48.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4470662/formats/png/48/download'}],
#      'size': 48,
#      'size_width': 48,
#      'size_height': 48},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn0.iconfinder.com/data/icons/uiux-001-line/32/UI_UX_UIUX_Back-64.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4470662/formats/png/64/download'}],
#      'size': 64,
#      'size_width': 64,
#      'size_height': 64},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn0.iconfinder.com/data/icons/uiux-001-line/32/UI_UX_UIUX_Back-128.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4470662/formats/png/128/download'}],
#      'size': 128,
#      'size_width': 128,
#      'size_height': 128},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn0.iconfinder.com/data/icons/uiux-001-line/32/UI_UX_UIUX_Back-256.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4470662/formats/png/256/download'}],
#      'size': 256,
#      'size_width': 256,
#      'size_height': 256},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn0.iconfinder.com/data/icons/uiux-001-line/32/UI_UX_UIUX_Back-512.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4470662/formats/png/512/download'}],
#      'size': 512,
#      'size_width': 512,
#      'size_height': 512},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn0.iconfinder.com/data/icons/uiux-001-line/32/UI_UX_UIUX_Back-1024.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4470662/formats/png/1024/download'}],
#      'size': 1024,
#      'size_width': 1024,
#      'size_height': 1024}],
#    'vector_sizes': [{'formats': [{'format': 'svg',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4470662/formats/svg/4942189/download'}],
#      'target_sizes': [[16, 20, 24, 32, 48, 64, 128, 256, 512, 1024]],
#      'size': 32,
#      'size_width': 32,
#      'size_height': 32}],
#    'styles': [{'identifier': 'outline', 'name': 'Outline'}],
#    'categories': [{'identifier': 'user-interface-optimal',
#      'name': 'User interface optimal'}],
#    'is_icon_glyph': False},
#   {'icon_id': 4476914,
#    'tags': ['forward',
#     'interface',
#     'mobile',
#     'next',
#     'ui',
#     'web icons',
#     'arrow'],
#    'published_at': '2019-04-07T08:43:55.043323Z',
#    'is_premium': False,
#    'type': 'vector',
#    'containers': [],
#    'raster_sizes': [{'formats': [{'format': 'png',
#        'preview_url': 'https://cdn1.iconfinder.com/data/icons/uiux-001-solid/32/Next-16.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4476914/formats/png/16/download'}],
#      'size': 16,
#      'size_width': 16,
#      'size_height': 16},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn1.iconfinder.com/data/icons/uiux-001-solid/32/Next-20.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4476914/formats/png/20/download'}],
#      'size': 20,
#      'size_width': 20,
#      'size_height': 20},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn1.iconfinder.com/data/icons/uiux-001-solid/32/Next-24.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4476914/formats/png/24/download'}],
#      'size': 24,
#      'size_width': 24,
#      'size_height': 24},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn1.iconfinder.com/data/icons/uiux-001-solid/32/Next-32.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4476914/formats/png/32/download'}],
#      'size': 32,
#      'size_width': 32,
#      'size_height': 32},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn1.iconfinder.com/data/icons/uiux-001-solid/32/Next-48.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4476914/formats/png/48/download'}],
#      'size': 48,
#      'size_width': 48,
#      'size_height': 48},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn1.iconfinder.com/data/icons/uiux-001-solid/32/Next-64.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4476914/formats/png/64/download'}],
#      'size': 64,
#      'size_width': 64,
#      'size_height': 64},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn1.iconfinder.com/data/icons/uiux-001-solid/32/Next-128.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4476914/formats/png/128/download'}],
#      'size': 128,
#      'size_width': 128,
#      'size_height': 128},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn1.iconfinder.com/data/icons/uiux-001-solid/32/Next-256.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4476914/formats/png/256/download'}],
#      'size': 256,
#      'size_width': 256,
#      'size_height': 256},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn1.iconfinder.com/data/icons/uiux-001-solid/32/Next-512.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4476914/formats/png/512/download'}],
#      'size': 512,
#      'size_width': 512,
#      'size_height': 512},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn1.iconfinder.com/data/icons/uiux-001-solid/32/Next-1024.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4476914/formats/png/1024/download'}],
#      'size': 1024,
#      'size_width': 1024,
#      'size_height': 1024}],
#    'vector_sizes': [{'formats': [{'format': 'svg',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4476914/formats/svg/4948442/download'}],
#      'target_sizes': [[16, 20, 24, 32, 48, 64, 128, 256, 512, 1024]],
#      'size': 32,
#      'size_width': 32,
#      'size_height': 32}],
#    'styles': [{'identifier': 'solid', 'name': 'Solid'}],
#    'categories': [{'identifier': 'user-interface-optimal',
#      'name': 'User interface optimal'}],
#    'is_icon_glyph': False},
#   {'icon_id': 211607,
#    'tags': ['right', 'arrow'],
#    'published_at': '2013-11-05T21:49:46.825431',
#    'is_premium': False,
#    'type': 'vector',
#    'containers': [{'format': 'ico',
#      'download_url': 'https://api.iconfinder.com/v4/icons/211607/containers/ico/download'},
#     {'format': 'icns',
#      'download_url': 'https://api.iconfinder.com/v4/icons/211607/containers/icns/download'}],
#    'raster_sizes': [{'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-ios7-arrow-right-16.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211607/formats/png/16/download'}],
#      'size': 16,
#      'size_width': 16,
#      'size_height': 16},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-ios7-arrow-right-20.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211607/formats/png/20/download'}],
#      'size': 20,
#      'size_width': 20,
#      'size_height': 20},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-ios7-arrow-right-24.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211607/formats/png/24/download'}],
#      'size': 24,
#      'size_width': 24,
#      'size_height': 24},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-ios7-arrow-right-32.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211607/formats/png/32/download'}],
#      'size': 32,
#      'size_width': 32,
#      'size_height': 32},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-ios7-arrow-right-48.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211607/formats/png/48/download'}],
#      'size': 48,
#      'size_width': 48,
#      'size_height': 48},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-ios7-arrow-right-64.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211607/formats/png/64/download'}],
#      'size': 64,
#      'size_width': 64,
#      'size_height': 64},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-ios7-arrow-right-128.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211607/formats/png/128/download'}],
#      'size': 128,
#      'size_width': 128,
#      'size_height': 128},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-ios7-arrow-right-256.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211607/formats/png/256/download'}],
#      'size': 256,
#      'size_width': 256,
#      'size_height': 256},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-ios7-arrow-right-512.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211607/formats/png/512/download'}],
#      'size': 512,
#      'size_width': 512,
#      'size_height': 512}],
#    'vector_sizes': [{'formats': [{'format': 'svg',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211607/formats/svg/568095/download'},
#       {'format': 'ai',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211607/formats/ai/568095/download'}],
#      'target_sizes': [[16, 20, 24, 32, 48, 64, 128, 256, 512]],
#      'size': 512,
#      'size_width': 512,
#      'size_height': 512}],
#    'styles': [{'identifier': 'solid', 'name': 'Solid'}],
#    'categories': [{'identifier': 'computer-hardware',
#      'name': 'Computer & hardware'}],
#    'is_icon_glyph': False},
#   {'icon_id': 4829869,
#    'tags': ['arrow', 'next', 'right'],
#    'published_at': '2019-07-04T06:06:30.437934',
#    'is_premium': False,
#    'type': 'vector',
#    'containers': [],
#    'raster_sizes': [{'formats': [{'format': 'png',
#        'preview_url': 'https://cdn3.iconfinder.com/data/icons/arrow-outline-8/32/right_2-16.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4829869/formats/png/16/download'}],
#      'size': 16,
#      'size_width': 16,
#      'size_height': 16},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn3.iconfinder.com/data/icons/arrow-outline-8/32/right_2-20.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4829869/formats/png/20/download'}],
#      'size': 20,
#      'size_width': 20,
#      'size_height': 20},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn3.iconfinder.com/data/icons/arrow-outline-8/32/right_2-24.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4829869/formats/png/24/download'}],
#      'size': 24,
#      'size_width': 24,
#      'size_height': 24},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn3.iconfinder.com/data/icons/arrow-outline-8/32/right_2-32.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4829869/formats/png/32/download'}],
#      'size': 32,
#      'size_width': 32,
#      'size_height': 32},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn3.iconfinder.com/data/icons/arrow-outline-8/32/right_2-48.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4829869/formats/png/48/download'}],
#      'size': 48,
#      'size_width': 48,
#      'size_height': 48},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn3.iconfinder.com/data/icons/arrow-outline-8/32/right_2-64.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4829869/formats/png/64/download'}],
#      'size': 64,
#      'size_width': 64,
#      'size_height': 64},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn3.iconfinder.com/data/icons/arrow-outline-8/32/right_2-128.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4829869/formats/png/128/download'}],
#      'size': 128,
#      'size_width': 128,
#      'size_height': 128},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn3.iconfinder.com/data/icons/arrow-outline-8/32/right_2-256.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4829869/formats/png/256/download'}],
#      'size': 256,
#      'size_width': 256,
#      'size_height': 256},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn3.iconfinder.com/data/icons/arrow-outline-8/32/right_2-512.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4829869/formats/png/512/download'}],
#      'size': 512,
#      'size_width': 512,
#      'size_height': 512},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn3.iconfinder.com/data/icons/arrow-outline-8/32/right_2-1024.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4829869/formats/png/1024/download'}],
#      'size': 1024,
#      'size_width': 1024,
#      'size_height': 1024}],
#    'vector_sizes': [{'formats': [{'format': 'svg',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4829869/formats/svg/5302618/download'}],
#      'target_sizes': [[16, 20, 24, 32, 48, 64, 128, 256, 512, 1024]],
#      'size': 32,
#      'size_width': 32,
#      'size_height': 32}],
#    'styles': [{'identifier': 'outline', 'name': 'Outline'}],
#    'categories': [{'identifier': 'arrow', 'name': 'Arrows'}],
#    'is_icon_glyph': False},
#   {'icon_id': 4600819,
#    'tags': ['arrow', 'chevron', 'down', 'scroll'],
#    'published_at': '2018-01-12T19:40:04.263746',
#    'is_premium': True,
#    'type': 'vector',
#    'containers': [],
#    'raster_sizes': [{'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/navigation-40/24/chevron-down-16.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4600819/formats/png/16/download'}],
#      'size': 16,
#      'size_width': 16,
#      'size_height': 16},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/navigation-40/24/chevron-down-20.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4600819/formats/png/20/download'}],
#      'size': 20,
#      'size_width': 20,
#      'size_height': 20},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/navigation-40/24/chevron-down-24.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4600819/formats/png/24/download'}],
#      'size': 24,
#      'size_width': 24,
#      'size_height': 24},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/navigation-40/24/chevron-down-32.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4600819/formats/png/32/download'}],
#      'size': 32,
#      'size_width': 32,
#      'size_height': 32},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/navigation-40/24/chevron-down-48.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4600819/formats/png/48/download'}],
#      'size': 48,
#      'size_width': 48,
#      'size_height': 48},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/navigation-40/24/chevron-down-64.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4600819/formats/png/64/download'}],
#      'size': 64,
#      'size_width': 64,
#      'size_height': 64},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/navigation-40/24/chevron-down-128.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4600819/formats/png/128/download'}],
#      'size': 128,
#      'size_width': 128,
#      'size_height': 128},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/navigation-40/24/chevron-down-256.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4600819/formats/png/256/download'}],
#      'size': 256,
#      'size_width': 256,
#      'size_height': 256},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/navigation-40/24/chevron-down-512.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4600819/formats/png/512/download'}],
#      'size': 512,
#      'size_width': 512,
#      'size_height': 512},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/navigation-40/24/chevron-down-1024.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4600819/formats/png/1024/download'}],
#      'size': 1024,
#      'size_width': 1024,
#      'size_height': 1024}],
#    'vector_sizes': [{'formats': [{'format': 'svg',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4600819/formats/svg/5072751/download'}],
#      'target_sizes': [[16, 20, 24, 32, 48, 64, 128, 256, 512, 1024]],
#      'size': 24,
#      'size_width': 24,
#      'size_height': 24}],
#    'prices': [{'license': {'license_id': 71,
#       'name': 'Basic license',
#       'url': 'https://www.iconfinder.com/licenses/basic',
#       'scope': 'basic'},
#      'currency': 'USD',
#      'price': 2.0}],
#    'styles': [{'identifier': 'outline', 'name': 'Outline'}],
#    'categories': [{'identifier': 'arrow', 'name': 'Arrows'},
#     {'identifier': 'user-interface-optimal',
#      'name': 'User interface optimal'}],
#    'is_purchased': False,
#    'is_icon_glyph': False},
#   {'icon_id': 211687,
#    'tags': ['down', 'arrow'],
#    'published_at': '2013-11-05T21:49:46.825431',
#    'is_premium': False,
#    'type': 'vector',
#    'containers': [{'format': 'ico',
#      'download_url': 'https://api.iconfinder.com/v4/icons/211687/containers/ico/download'},
#     {'format': 'icns',
#      'download_url': 'https://api.iconfinder.com/v4/icons/211687/containers/icns/download'}],
#    'raster_sizes': [{'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-ios7-arrow-down-16.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211687/formats/png/16/download'}],
#      'size': 16,
#      'size_width': 16,
#      'size_height': 16},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-ios7-arrow-down-20.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211687/formats/png/20/download'}],
#      'size': 20,
#      'size_width': 20,
#      'size_height': 20},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-ios7-arrow-down-24.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211687/formats/png/24/download'}],
#      'size': 24,
#      'size_width': 24,
#      'size_height': 24},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-ios7-arrow-down-32.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211687/formats/png/32/download'}],
#      'size': 32,
#      'size_width': 32,
#      'size_height': 32},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-ios7-arrow-down-48.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211687/formats/png/48/download'}],
#      'size': 48,
#      'size_width': 48,
#      'size_height': 48},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-ios7-arrow-down-64.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211687/formats/png/64/download'}],
#      'size': 64,
#      'size_width': 64,
#      'size_height': 64},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-ios7-arrow-down-128.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211687/formats/png/128/download'}],
#      'size': 128,
#      'size_width': 128,
#      'size_height': 128},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-ios7-arrow-down-256.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211687/formats/png/256/download'}],
#      'size': 256,
#      'size_width': 256,
#      'size_height': 256},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-ios7-arrow-down-512.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211687/formats/png/512/download'}],
#      'size': 512,
#      'size_width': 512,
#      'size_height': 512}],
#    'vector_sizes': [{'formats': [{'format': 'svg',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211687/formats/svg/568175/download'},
#       {'format': 'ai',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211687/formats/ai/568175/download'}],
#      'target_sizes': [[16, 20, 24, 32, 48, 64, 128, 256, 512]],
#      'size': 512,
#      'size_width': 512,
#      'size_height': 512}],
#    'styles': [{'identifier': 'solid', 'name': 'Solid'}],
#    'categories': [{'identifier': 'computer-hardware',
#      'name': 'Computer & hardware'}],
#    'is_icon_glyph': False},
#   {'icon_id': 4600821,
#    'tags': ['arrow', 'chevron', 'next', 'right'],
#    'published_at': '2018-01-12T19:40:04.263746',
#    'is_premium': True,
#    'type': 'vector',
#    'containers': [],
#    'raster_sizes': [{'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/navigation-40/24/chevron-right-16.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4600821/formats/png/16/download'}],
#      'size': 16,
#      'size_width': 16,
#      'size_height': 16},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/navigation-40/24/chevron-right-20.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4600821/formats/png/20/download'}],
#      'size': 20,
#      'size_width': 20,
#      'size_height': 20},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/navigation-40/24/chevron-right-24.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4600821/formats/png/24/download'}],
#      'size': 24,
#      'size_width': 24,
#      'size_height': 24},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/navigation-40/24/chevron-right-32.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4600821/formats/png/32/download'}],
#      'size': 32,
#      'size_width': 32,
#      'size_height': 32},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/navigation-40/24/chevron-right-48.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4600821/formats/png/48/download'}],
#      'size': 48,
#      'size_width': 48,
#      'size_height': 48},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/navigation-40/24/chevron-right-64.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4600821/formats/png/64/download'}],
#      'size': 64,
#      'size_width': 64,
#      'size_height': 64},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/navigation-40/24/chevron-right-128.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4600821/formats/png/128/download'}],
#      'size': 128,
#      'size_width': 128,
#      'size_height': 128},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/navigation-40/24/chevron-right-256.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4600821/formats/png/256/download'}],
#      'size': 256,
#      'size_width': 256,
#      'size_height': 256},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/navigation-40/24/chevron-right-512.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4600821/formats/png/512/download'}],
#      'size': 512,
#      'size_width': 512,
#      'size_height': 512},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/navigation-40/24/chevron-right-1024.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4600821/formats/png/1024/download'}],
#      'size': 1024,
#      'size_width': 1024,
#      'size_height': 1024}],
#    'vector_sizes': [{'formats': [{'format': 'svg',
#        'download_url': 'https://api.iconfinder.com/v4/icons/4600821/formats/svg/5072753/download'}],
#      'target_sizes': [[16, 20, 24, 32, 48, 64, 128, 256, 512, 1024]],
#      'size': 24,
#      'size_width': 24,
#      'size_height': 24}],
#    'prices': [{'license': {'license_id': 71,
#       'name': 'Basic license',
#       'url': 'https://www.iconfinder.com/licenses/basic',
#       'scope': 'basic'},
#      'currency': 'USD',
#      'price': 2.0}],
#    'styles': [{'identifier': 'outline', 'name': 'Outline'}],
#    'categories': [{'identifier': 'arrow', 'name': 'Arrows'},
#     {'identifier': 'user-interface-optimal',
#      'name': 'User interface optimal'}],
#    'is_purchased': False,
#    'is_icon_glyph': False},
#   {'icon_id': 211688,
#    'tags': ['forward', 'arrow'],
#    'published_at': '2013-11-05T21:49:46.825431',
#    'is_premium': False,
#    'type': 'vector',
#    'containers': [{'format': 'ico',
#      'download_url': 'https://api.iconfinder.com/v4/icons/211688/containers/ico/download'},
#     {'format': 'icns',
#      'download_url': 'https://api.iconfinder.com/v4/icons/211688/containers/icns/download'}],
#    'raster_sizes': [{'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-ios7-arrow-forward-16.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211688/formats/png/16/download'}],
#      'size': 16,
#      'size_width': 16,
#      'size_height': 16},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-ios7-arrow-forward-20.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211688/formats/png/20/download'}],
#      'size': 20,
#      'size_width': 20,
#      'size_height': 20},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-ios7-arrow-forward-24.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211688/formats/png/24/download'}],
#      'size': 24,
#      'size_width': 24,
#      'size_height': 24},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-ios7-arrow-forward-32.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211688/formats/png/32/download'}],
#      'size': 32,
#      'size_width': 32,
#      'size_height': 32},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-ios7-arrow-forward-48.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211688/formats/png/48/download'}],
#      'size': 48,
#      'size_width': 48,
#      'size_height': 48},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-ios7-arrow-forward-64.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211688/formats/png/64/download'}],
#      'size': 64,
#      'size_width': 64,
#      'size_height': 64},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-ios7-arrow-forward-128.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211688/formats/png/128/download'}],
#      'size': 128,
#      'size_width': 128,
#      'size_height': 128},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-ios7-arrow-forward-256.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211688/formats/png/256/download'}],
#      'size': 256,
#      'size_width': 256,
#      'size_height': 256},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-ios7-arrow-forward-512.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211688/formats/png/512/download'}],
#      'size': 512,
#      'size_width': 512,
#      'size_height': 512}],
#    'vector_sizes': [{'formats': [{'format': 'svg',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211688/formats/svg/568176/download'},
#       {'format': 'ai',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211688/formats/ai/568176/download'}],
#      'target_sizes': [[16, 20, 24, 32, 48, 64, 128, 256, 512]],
#      'size': 512,
#      'size_width': 512,
#      'size_height': 512}],
#    'styles': [{'identifier': 'solid', 'name': 'Solid'}],
#    'categories': [{'identifier': 'computer-hardware',
#      'name': 'Computer & hardware'}],
#    'is_icon_glyph': False},
#   {'icon_id': 1514956,
#    'tags': ['arrow', 'corrections', 'drawn', 'direction'],
#    'published_at': '2016-10-04T19:21:10.249944Z',
#    'is_premium': True,
#    'type': 'vector',
#    'containers': [{'format': 'ico',
#      'download_url': 'https://api.iconfinder.com/v4/icons/1514956/containers/ico/download'},
#     {'format': 'icns',
#      'download_url': 'https://api.iconfinder.com/v4/icons/1514956/containers/icns/download'}],
#    'raster_sizes': [{'formats': [{'format': 'png',
#        'preview_url': 'https://cdn1.iconfinder.com/data/icons/hand-drawn-corrections/100/hand_drawn_corrections-14-16.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/1514956/formats/png/16/download'}],
#      'size': 16,
#      'size_width': 16,
#      'size_height': 16},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn1.iconfinder.com/data/icons/hand-drawn-corrections/100/hand_drawn_corrections-14-20.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/1514956/formats/png/20/download'}],
#      'size': 20,
#      'size_width': 20,
#      'size_height': 20},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn1.iconfinder.com/data/icons/hand-drawn-corrections/100/hand_drawn_corrections-14-24.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/1514956/formats/png/24/download'}],
#      'size': 24,
#      'size_width': 24,
#      'size_height': 24},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn1.iconfinder.com/data/icons/hand-drawn-corrections/100/hand_drawn_corrections-14-32.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/1514956/formats/png/32/download'}],
#      'size': 32,
#      'size_width': 32,
#      'size_height': 32},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn1.iconfinder.com/data/icons/hand-drawn-corrections/100/hand_drawn_corrections-14-48.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/1514956/formats/png/48/download'}],
#      'size': 48,
#      'size_width': 48,
#      'size_height': 48},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn1.iconfinder.com/data/icons/hand-drawn-corrections/100/hand_drawn_corrections-14-64.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/1514956/formats/png/64/download'}],
#      'size': 64,
#      'size_width': 64,
#      'size_height': 64},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn1.iconfinder.com/data/icons/hand-drawn-corrections/100/hand_drawn_corrections-14-128.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/1514956/formats/png/128/download'}],
#      'size': 128,
#      'size_width': 128,
#      'size_height': 128},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn1.iconfinder.com/data/icons/hand-drawn-corrections/100/hand_drawn_corrections-14-256.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/1514956/formats/png/256/download'}],
#      'size': 256,
#      'size_width': 256,
#      'size_height': 256},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn1.iconfinder.com/data/icons/hand-drawn-corrections/100/hand_drawn_corrections-14-512.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/1514956/formats/png/512/download'}],
#      'size': 512,
#      'size_width': 512,
#      'size_height': 512},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn1.iconfinder.com/data/icons/hand-drawn-corrections/100/hand_drawn_corrections-14-1024.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/1514956/formats/png/1024/download'}],
#      'size': 1024,
#      'size_width': 1024,
#      'size_height': 1024}],
#    'vector_sizes': [{'formats': [{'format': 'svg',
#        'download_url': 'https://api.iconfinder.com/v4/icons/1514956/formats/svg/1958927/download'},
#       {'format': 'ai',
#        'download_url': 'https://api.iconfinder.com/v4/icons/1514956/formats/ai/1958927/download'}],
#      'target_sizes': [[16, 20, 24, 32, 48, 64, 128, 256, 512, 1024]],
#      'size': 100,
#      'size_width': 100,
#      'size_height': 100}],
#    'prices': [{'license': {'license_id': 71,
#       'name': 'Basic license',
#       'url': 'https://www.iconfinder.com/licenses/basic',
#       'scope': 'basic'},
#      'currency': 'USD',
#      'price': 2.0}],
#    'styles': [{'identifier': 'handdrawn', 'name': 'Handdrawn'}],
#    'categories': [{'identifier': 'arrow', 'name': 'Arrows'}],
#    'is_purchased': False,
#    'is_icon_glyph': False},
#   {'icon_id': 211614,
#    'tags': ['down', 'b', 'arrow'],
#    'published_at': '2013-11-05T21:49:46.825431',
#    'is_premium': False,
#    'type': 'vector',
#    'containers': [{'format': 'ico',
#      'download_url': 'https://api.iconfinder.com/v4/icons/211614/containers/ico/download'},
#     {'format': 'icns',
#      'download_url': 'https://api.iconfinder.com/v4/icons/211614/containers/icns/download'}],
#    'raster_sizes': [{'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-arrow-down-b-16.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211614/formats/png/16/download'}],
#      'size': 16,
#      'size_width': 16,
#      'size_height': 16},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-arrow-down-b-20.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211614/formats/png/20/download'}],
#      'size': 20,
#      'size_width': 20,
#      'size_height': 20},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-arrow-down-b-24.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211614/formats/png/24/download'}],
#      'size': 24,
#      'size_width': 24,
#      'size_height': 24},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-arrow-down-b-32.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211614/formats/png/32/download'}],
#      'size': 32,
#      'size_width': 32,
#      'size_height': 32},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-arrow-down-b-48.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211614/formats/png/48/download'}],
#      'size': 48,
#      'size_width': 48,
#      'size_height': 48},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-arrow-down-b-64.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211614/formats/png/64/download'}],
#      'size': 64,
#      'size_width': 64,
#      'size_height': 64},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-arrow-down-b-128.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211614/formats/png/128/download'}],
#      'size': 128,
#      'size_width': 128,
#      'size_height': 128},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-arrow-down-b-256.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211614/formats/png/256/download'}],
#      'size': 256,
#      'size_width': 256,
#      'size_height': 256},
#     {'formats': [{'format': 'png',
#        'preview_url': 'https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-arrow-down-b-512.png',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211614/formats/png/512/download'}],
#      'size': 512,
#      'size_width': 512,
#      'size_height': 512}],
#    'vector_sizes': [{'formats': [{'format': 'svg',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211614/formats/svg/568102/download'},
#       {'format': 'ai',
#        'download_url': 'https://api.iconfinder.com/v4/icons/211614/formats/ai/568102/download'}],
#      'target_sizes': [[16, 20, 24, 32, 48, 64, 128, 256, 512]],
#      'size': 512,
#      'size_width': 512,
#      'size_height': 512}],
#    'styles': [{'identifier': 'solid', 'name': 'Solid'}],
#    'categories': [{'identifier': 'computer-hardware',
#      'name': 'Computer & hardware'}],
#    'is_icon_glyph': False}]}

# %% [markdown]
# #**Illusion Diffusion**

# %%
url="https://54285744-illusion-diffusion.gateway.alpha.fal.ai/"

Fal_API_KEY=os.getenv("Fal_API_KEY")

headers = {
    "Authorization": Fal_API_KEY,
    "Content-Type": "application/json"
}
payload={
  "image_url": "https://storage.googleapis.com/falserverless/illusion-examples/funky.jpeg",
  "prompt": "(masterpiece:1.4), (best quality), (detailed),dance girls in iran  ",
  "negative_prompt": "(worst quality, poor details:1.4), lowres, (artist name, signature, watermark:1.4), bad-artist-anime, bad_prompt_version2, bad-hands-5, ng_deepnegative_v1_75t",

}



response = requests.post(url, json=payload, headers=headers)
response.status_code
# Out:
# 200

# %%
json.loads(response.text)
# Out:
# {'image': {'url': 'https://storage.googleapis.com/isolate-dev-hot-rooster_toolkit_bucket/github_54285744/c49ec2a9bdb347ac86878d7eaaa6211a.png?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gke-service-account%40isolate-dev-hot-rooster.iam.gserviceaccount.com%2F20240316%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240316T094722Z&X-Goog-Expires=604800&X-Goog-SignedHeaders=host&X-Goog-Signature=...',
#   'content_type': 'image/png',
#   'file_name': 'c49ec2a9bdb347ac86878d7eaaa6211a.png',
#   'file_size': 1810650,
#   'width': 1024,
#   'height': 1024},
#  'seed': 7732169920497976}

# %%
response.text
# Out:
# '{"image":{"url":"https://storage.googleapis.com/isolate-dev-hot-rooster_toolkit_bucket/github_54285744/c49ec2a9bdb347ac86878d7eaaa6211a.png?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gke-service-account%40isolate-dev-hot-rooster.iam.gserviceaccount.com%2F20240316%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240316T094722Z&X-Goog-Expires=604800&X-Goog-SignedHeaders=host&X-Goog-Signature=...","content_type":"image/png","file_name":"c49ec2a9bdb347ac86878d7eaaa6211a.png","file_size":1810650,"width":1024,"height":1024},"seed":7732169920497976}'

# %% [markdown]
# #**D-ID**

# %% [markdown]
# ###presenters

# %%
import requests

url = "https://api.d-id.com/clips/presenters"

D_iD_API_KEY=os.getenv("D_iD_API_KEY")

headers = {
    "accept": "application/json",
    "authorization": D_iD_API_KEY
}

response = requests.get(url, headers=headers)

# %%
response.json()
# Out:
# {'presenters': [{'presenter_id': 'rian-pbMoTzs7an',
#    'created_at': '2023-08-20T12:53:44.254Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/rian/pbMoTzs7an/vmcS2q23Kk/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/rian/pbMoTzs7an/vmcS2q23Kk/preview.mp4',
#    'driver_id': 'vmcS2q23Kk',
#    'image_url': 'https://clips-presenters.d-id.com/rian/pbMoTzs7an/vmcS2q23Kk/image.png',
#    'gender': 'male',
#    'model_url': 's3://d-id-clips-drivers-prod/rian/pbMoTzs7an/generator.pt',
#    'modified_at': '2023-09-27T11:06:44.603Z',
#    'owner_id': ''},
#   {'presenter_id': 'rian-lZC6MmWfC1',
#    'created_at': '2023-08-20T12:53:52.505Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/rian/lZC6MmWfC1/mXra4jY38i/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/rian/lZC6MmWfC1/mXra4jY38i/preview.mp4',
#    'driver_id': 'mXra4jY38i',
#    'image_url': 'https://clips-presenters.d-id.com/rian/lZC6MmWfC1/mXra4jY38i/image.png',
#    'gender': 'male',
#    'model_url': 's3://d-id-clips-drivers-prod/rian/lZC6MmWfC1/generator.pt',
#    'modified_at': '2023-09-27T11:06:42.910Z',
#    'owner_id': ''},
#   {'presenter_id': 'rian-bYZilf8Qr9',
#    'created_at': '2023-08-20T12:54:07.568Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/rian/bYZilf8Qr9/UoaR8NoiQo/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/rian/bYZilf8Qr9/UoaR8NoiQo/preview.mp4',
#    'driver_id': 'UoaR8NoiQo',
#    'image_url': 'https://clips-presenters.d-id.com/rian/bYZilf8Qr9/UoaR8NoiQo/image.png',
#    'gender': 'male',
#    'model_url': 's3://d-id-clips-drivers-prod/rian/bYZilf8Qr9/generator.pt',
#    'modified_at': '2023-09-27T11:06:41.412Z',
#    'owner_id': ''},
#   {'presenter_id': 'lana-uXbrIxQFjr',
#    'created_at': '2023-08-21T14:08:49.519Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/lana/uXbrIxQFjr/kzlKYBZ2wc/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/lana/uXbrIxQFjr/kzlKYBZ2wc/preview.mp4',
#    'driver_id': 'kzlKYBZ2wc',
#    'image_url': 'https://clips-presenters.d-id.com/lana/uXbrIxQFjr/kzlKYBZ2wc/image.png',
#    'gender': 'female',
#    'model_url': 's3://d-id-clips-drivers-prod/lana/uXbrIxQFjr/generator.pt',
#    'modified_at': '2023-09-27T11:07:28.531Z',
#    'owner_id': ''},
#   {'presenter_id': 'lana-lr0vlC_700',
#    'created_at': '2023-08-21T14:08:55.663Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/lana/lr0vlC_700/yqPgAF9PfJ/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/lana/lr0vlC_700/yqPgAF9PfJ/preview.mp4',
#    'driver_id': 'yqPgAF9PfJ',
#    'image_url': 'https://clips-presenters.d-id.com/lana/lr0vlC_700/yqPgAF9PfJ/image.png',
#    'gender': 'female',
#    'model_url': 's3://d-id-clips-drivers-prod/lana/lr0vlC_700/generator.pt',
#    'modified_at': '2023-09-27T11:07:27.094Z',
#    'owner_id': ''},
#   {'presenter_id': 'lana-GSXf7xHFoX',
#    'created_at': '2023-08-21T14:09:07.247Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/lana/GSXf7xHFoX/ZJ2mcgCRy9/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/lana/GSXf7xHFoX/ZJ2mcgCRy9/preview.mp4',
#    'driver_id': 'ZJ2mcgCRy9',
#    'image_url': 'https://clips-presenters.d-id.com/lana/GSXf7xHFoX/ZJ2mcgCRy9/image.png',
#    'gender': 'female',
#    'model_url': 's3://d-id-clips-drivers-prod/lana/GSXf7xHFoX/generator.pt',
#    'modified_at': '2023-09-27T11:07:25.568Z',
#    'owner_id': ''},
#   {'presenter_id': 'jack-Pt27VkP3hW',
#    'created_at': '2023-08-21T17:14:19.629Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/jack/Pt27VkP3hW/fbQicImV2J/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/jack/Pt27VkP3hW/fbQicImV2J/preview.mp4',
#    'driver_id': 'fbQicImV2J',
#    'image_url': 'https://clips-presenters.d-id.com/jack/Pt27VkP3hW/fbQicImV2J/image.png',
#    'gender': 'male',
#    'model_url': 's3://d-id-clips-drivers-prod/jack/Pt27VkP3hW/generator.pt',
#    'modified_at': '2023-09-27T11:07:47.664Z',
#    'owner_id': ''},
#   {'presenter_id': 'jack-MVemepZhiL',
#    'created_at': '2023-08-21T17:14:28.329Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/jack/MVemepZhiL/Q_Te_y3FxY/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/jack/MVemepZhiL/Q_Te_y3FxY/preview.mp4',
#    'driver_id': 'Q_Te_y3FxY',
#    'image_url': 'https://clips-presenters.d-id.com/jack/MVemepZhiL/Q_Te_y3FxY/image.png',
#    'gender': 'male',
#    'model_url': 's3://d-id-clips-drivers-prod/jack/MVemepZhiL/generator.pt',
#    'modified_at': '2023-09-27T11:07:46.096Z',
#    'owner_id': ''},
#   {'presenter_id': 'jack-KVaDW71ltd',
#    'created_at': '2023-08-21T17:14:42.080Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/jack/KVaDW71ltd/yShno7kWlz/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/jack/KVaDW71ltd/yShno7kWlz/preview.mp4',
#    'driver_id': 'yShno7kWlz',
#    'image_url': 'https://clips-presenters.d-id.com/jack/KVaDW71ltd/yShno7kWlz/image.png',
#    'gender': 'male',
#    'model_url': 's3://d-id-clips-drivers-prod/jack/KVaDW71ltd/generator.pt',
#    'modified_at': '2023-09-27T11:07:43.667Z',
#    'owner_id': ''},
#   {'presenter_id': 'matt-g7muIj5CiD',
#    'created_at': '2023-08-22T16:16:50.292Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/matt/g7muIj5CiD/w8bWNn8GSl/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/matt/g7muIj5CiD/w8bWNn8GSl/preview.mp4',
#    'driver_id': 'w8bWNn8GSl',
#    'image_url': 'https://clips-presenters.d-id.com/matt/g7muIj5CiD/w8bWNn8GSl/image.png',
#    'gender': 'male',
#    'model_url': 's3://d-id-clips-drivers-prod/matt/g7muIj5CiD/generator.pt',
#    'modified_at': '2023-09-27T11:06:55.521Z',
#    'owner_id': ''},
#   {'presenter_id': 'matt-PEvEohn_gk',
#    'created_at': '2023-08-22T16:16:55.846Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/matt/PEvEohn_gk/hOIr_2INMA/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/matt/PEvEohn_gk/hOIr_2INMA/preview.mp4',
#    'driver_id': 'hOIr_2INMA',
#    'image_url': 'https://clips-presenters.d-id.com/matt/PEvEohn_gk/hOIr_2INMA/image.png',
#    'gender': 'male',
#    'model_url': 's3://d-id-clips-drivers-prod/matt/PEvEohn_gk/generator.pt',
#    'modified_at': '2023-09-27T11:06:53.923Z',
#    'owner_id': ''},
#   {'presenter_id': 'lily-ADdf3C9AUh',
#    'created_at': '2023-08-23T11:29:09.354Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/lily/ADdf3C9AUh/ua2JndzsX1/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/lily/ADdf3C9AUh/ua2JndzsX1/preview.mp4',
#    'driver_id': 'ua2JndzsX1',
#    'image_url': 'https://clips-presenters.d-id.com/lily/ADdf3C9AUh/ua2JndzsX1/image.png',
#    'gender': 'female',
#    'model_url': 's3://d-id-clips-drivers-prod/lily/ADdf3C9AUh/generator.pt',
#    'modified_at': '2023-09-27T11:07:35.162Z',
#    'owner_id': ''},
#   {'presenter_id': 'lily-akobXDF34M',
#    'created_at': '2023-08-23T11:29:33.257Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/lily/akobXDF34M/oqNen3Q3aS/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/lily/akobXDF34M/oqNen3Q3aS/preview.mp4',
#    'driver_id': 'oqNen3Q3aS',
#    'image_url': 'https://clips-presenters.d-id.com/lily/akobXDF34M/oqNen3Q3aS/image.png',
#    'gender': 'female',
#    'model_url': 's3://d-id-clips-drivers-prod/lily/akobXDF34M/generator.pt',
#    'modified_at': '2023-09-27T11:07:37.900Z',
#    'owner_id': ''},
#   {'presenter_id': 'lily-ldwi8a_LdG',
#    'created_at': '2023-08-23T11:29:46.182Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/lily/ldwi8a_LdG/Zz10FZua2P/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/lily/ldwi8a_LdG/Zz10FZua2P/preview.mp4',
#    'driver_id': 'Zz10FZua2P',
#    'image_url': 'https://clips-presenters.d-id.com/lily/ldwi8a_LdG/Zz10FZua2P/image.png',
#    'gender': 'female',
#    'model_url': 's3://d-id-clips-drivers-prod/lily/ldwi8a_LdG/generator.pt',
#    'modified_at': '2023-09-27T11:07:41.043Z',
#    'owner_id': ''},
#   {'presenter_id': 'matt-9C51DD6lgH',
#    'created_at': '2023-08-24T08:50:45.204Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/matt/9C51DD6lgH/mBHOFBuOHq/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/matt/9C51DD6lgH/mBHOFBuOHq/preview.mp4',
#    'driver_id': 'mBHOFBuOHq',
#    'image_url': 'https://clips-presenters.d-id.com/matt/9C51DD6lgH/mBHOFBuOHq/image.png',
#    'gender': 'male',
#    'model_url': 's3://d-id-clips-drivers-prod/matt/9C51DD6lgH/generator.pt',
#    'modified_at': '2023-09-27T11:06:50.701Z',
#    'owner_id': ''},
#   {'presenter_id': 'amy-Aq6OmGZnMt',
#    'created_at': '2023-10-04T11:40:08.194Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/amy/Aq6OmGZnMt/Vcq0R4a8F0/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/amy/Aq6OmGZnMt/Vcq0R4a8F0/preview.mp4',
#    'driver_id': 'Vcq0R4a8F0',
#    'image_url': 'https://clips-presenters.d-id.com/amy/Aq6OmGZnMt/Vcq0R4a8F0/image.png',
#    'gender': 'female',
#    'model_url': 's3://d-id-clips-drivers-prod/amy/Aq6OmGZnMt/generator.pt',
#    'modified_at': '2023-10-04T11:40:08.194Z',
#    'owner_id': ''},
#   {'presenter_id': 'amy-FLZ1USJl7m',
#    'created_at': '2023-10-04T11:40:37.530Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/amy/FLZ1USJl7m/vzswgDCwKZ/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/amy/FLZ1USJl7m/vzswgDCwKZ/preview.mp4',
#    'driver_id': 'vzswgDCwKZ',
#    'image_url': 'https://clips-presenters.d-id.com/amy/FLZ1USJl7m/vzswgDCwKZ/image.png',
#    'gender': 'female',
#    'model_url': 's3://d-id-clips-drivers-prod/amy/FLZ1USJl7m/generator.pt',
#    'modified_at': '2023-10-04T11:40:37.530Z',
#    'owner_id': ''},
#   {'presenter_id': 'amy-sEIU0O2gBy',
#    'created_at': '2023-10-04T11:40:44.828Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/amy/sEIU0O2gBy/VrHMAOUSgO/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/amy/sEIU0O2gBy/VrHMAOUSgO/preview.mp4',
#    'driver_id': 'VrHMAOUSgO',
#    'image_url': 'https://clips-presenters.d-id.com/amy/sEIU0O2gBy/VrHMAOUSgO/image.png',
#    'gender': 'female',
#    'model_url': 's3://d-id-clips-drivers-prod/amy/sEIU0O2gBy/generator.pt',
#    'modified_at': '2023-10-04T11:40:44.828Z',
#    'owner_id': ''},
#   {'presenter_id': 'joseph-ivRs8CUnJ8',
#    'created_at': '2023-10-29T14:20:11.333Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/joseph/ivRs8CUnJ8/Ypn6DPLyo8/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/joseph/ivRs8CUnJ8/Ypn6DPLyo8/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/joseph/ivRs8CUnJ8/Ypn6DPLyo8/image.png',
#    'gender': 'male',
#    'model_url': 's3://d-id-clips-drivers-prod/joseph/ivRs8CUnJ8/generator.pt',
#    'modified_at': '2023-10-29T14:20:11.333Z',
#    'owner_id': ''},
#   {'presenter_id': 'anita-6_uTzyZtNR',
#    'created_at': '2023-10-29T14:20:45.081Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/anita/6_uTzyZtNR/vxfRIwlzuf/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/anita/6_uTzyZtNR/vxfRIwlzuf/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/anita/6_uTzyZtNR/vxfRIwlzuf/image.png',
#    'gender': 'female',
#    'model_url': 's3://d-id-clips-drivers-prod/anita/6_uTzyZtNR/generator.pt',
#    'modified_at': '2023-10-29T14:20:45.081Z',
#    'owner_id': ''},
#   {'presenter_id': 'joseph-q_9lGHtyYX',
#    'created_at': '2023-10-31T08:15:53.534Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/joseph/q_9lGHtyYX/d6NpIaT7xt/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/joseph/q_9lGHtyYX/d6NpIaT7xt/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/joseph/q_9lGHtyYX/d6NpIaT7xt/image.png',
#    'gender': 'male',
#    'model_url': 's3://d-id-clips-drivers-prod/joseph/q_9lGHtyYX/generator.pt',
#    'modified_at': '2023-10-31T08:15:53.534Z',
#    'owner_id': ''},
#   {'presenter_id': 'alyssa-z1fn0H3BfK',
#    'created_at': '2023-10-31T09:29:45.093Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/alyssa/z1fn0H3BfK/bSMgcAjT2R/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/alyssa/z1fn0H3BfK/bSMgcAjT2R/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/alyssa/z1fn0H3BfK/bSMgcAjT2R/image.png',
#    'gender': 'female',
#    'model_url': 's3://d-id-clips-drivers-prod/alyssa/z1fn0H3BfK/generator.pt',
#    'modified_at': '2023-10-31T09:29:45.093Z',
#    'owner_id': ''},
#   {'presenter_id': 'eugene-HlNYlOU01E',
#    'created_at': '2023-11-05T08:09:44.094Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/eugene/HlNYlOU01E/Nn2TNiltOZ/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/eugene/HlNYlOU01E/Nn2TNiltOZ/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/eugene/HlNYlOU01E/Nn2TNiltOZ/image.png',
#    'gender': 'male',
#    'model_url': 's3://d-id-clips-drivers-prod/eugene/HlNYlOU01E/generator.pt',
#    'modified_at': '2023-11-05T08:09:44.094Z',
#    'owner_id': ''},
#   {'presenter_id': 'ella-gnVGWQ_kNS',
#    'created_at': '2023-11-05T08:13:31.420Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/ella/gnVGWQ_kNS/ypXXYSLJAP/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/ella/gnVGWQ_kNS/ypXXYSLJAP/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/ella/gnVGWQ_kNS/ypXXYSLJAP/image.png',
#    'gender': 'female',
#    'model_url': 's3://d-id-clips-drivers-prod/ella/gnVGWQ_kNS/generator.pt',
#    'modified_at': '2023-11-05T08:13:31.420Z',
#    'owner_id': ''},
#   {'presenter_id': 'dylan-O22mVF9zIM',
#    'created_at': '2023-11-05T14:16:42.641Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/dylan/O22mVF9zIM/T_23LQNrEm/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/dylan/O22mVF9zIM/T_23LQNrEm/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/dylan/O22mVF9zIM/T_23LQNrEm/image.png',
#    'gender': 'male',
#    'model_url': 's3://d-id-clips-drivers-prod/dylan/O22mVF9zIM/generator.pt',
#    'modified_at': '2023-11-05T14:16:42.641Z',
#    'owner_id': ''},
#   {'presenter_id': 'dylan-dR5EU1bI9z',
#    'created_at': '2023-11-08T11:30:33.451Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/dylan/dR5EU1bI9z/fsiednoqqb/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/dylan/dR5EU1bI9z/fsiednoqqb/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/dylan/dR5EU1bI9z/fsiednoqqb/image.png',
#    'gender': 'male',
#    'model_url': 's3://d-id-clips-drivers-prod/dylan/dR5EU1bI9z/generator.pt',
#    'modified_at': '2023-11-08T11:30:33.451Z',
#    'owner_id': ''},
#   {'presenter_id': 'frank-gvlo7vAP2C',
#    'created_at': '2023-11-08T11:34:00.373Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/frank/gvlo7vAP2C/0iyjivUbhC/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/frank/gvlo7vAP2C/0iyjivUbhC/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/frank/gvlo7vAP2C/0iyjivUbhC/image.png',
#    'gender': 'male',
#    'model_url': 's3://d-id-clips-drivers-prod/frank/gvlo7vAP2C/generator.pt',
#    'modified_at': '2023-11-08T11:34:00.373Z',
#    'owner_id': ''},
#   {'presenter_id': 'jaimie-mhQav1eFuW',
#    'created_at': '2023-11-12T08:01:07.140Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/jaimie/mhQav1eFuW/sulQhOcoQj/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/jaimie/mhQav1eFuW/sulQhOcoQj/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/jaimie/mhQav1eFuW/sulQhOcoQj/image.png',
#    'gender': 'male',
#    'model_url': 's3://d-id-clips-drivers-prod/jaimie/mhQav1eFuW/generator.pt',
#    'modified_at': '2023-11-12T08:01:07.140Z',
#    'owner_id': ''},
#   {'presenter_id': 'flora-4BdcfiQNJP',
#    'created_at': '2023-11-12T08:04:37.148Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/flora/4BdcfiQNJP/BQPMRVyolw/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/flora/4BdcfiQNJP/BQPMRVyolw/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/flora/4BdcfiQNJP/BQPMRVyolw/image.png',
#    'gender': 'female',
#    'model_url': 's3://d-id-clips-drivers-prod/flora/4BdcfiQNJP/generator.pt',
#    'modified_at': '2023-11-12T08:04:37.148Z',
#    'owner_id': ''},
#   {'presenter_id': 'sophia-utD_M2P2Lk',
#    'created_at': '2023-11-12T08:05:24.323Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/sophia/utD_M2P2Lk/UDQ63gY5Sv/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/sophia/utD_M2P2Lk/UDQ63gY5Sv/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/sophia/utD_M2P2Lk/UDQ63gY5Sv/image.png',
#    'gender': 'female',
#    'model_url': 's3://d-id-clips-drivers-prod/sophia/utD_M2P2Lk/generator.pt',
#    'modified_at': '2023-11-12T08:05:24.323Z',
#    'owner_id': ''},
#   {'presenter_id': 'arran-E2OXQyzs_r',
#    'created_at': '2023-11-12T08:10:33.153Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/arran/E2OXQyzs_r/PaHFW_LIWB/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/arran/E2OXQyzs_r/PaHFW_LIWB/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/arran/E2OXQyzs_r/PaHFW_LIWB/image.png',
#    'gender': 'male',
#    'model_url': 's3://d-id-clips-drivers-prod/arran/E2OXQyzs_r/generator.pt',
#    'modified_at': '2023-11-12T08:10:33.153Z',
#    'owner_id': ''},
#   {'presenter_id': 'mary-26F6sVe7Yg',
#    'created_at': '2023-11-12T08:53:36.022Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/mary/26F6sVe7Yg/ujy8kGzgSJ/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/mary/26F6sVe7Yg/ujy8kGzgSJ/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/mary/26F6sVe7Yg/ujy8kGzgSJ/image.png',
#    'gender': 'female',
#    'model_url': 's3://d-id-clips-drivers-prod/mary/26F6sVe7Yg/generator.pt',
#    'modified_at': '2023-11-12T08:53:36.023Z',
#    'owner_id': ''},
#   {'presenter_id': 'kayla-zxpG_93n5W',
#    'created_at': '2023-11-14T08:28:29.881Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/kayla/zxpG_93n5W/E55gCKZ8lx/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/kayla/zxpG_93n5W/E55gCKZ8lx/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/kayla/zxpG_93n5W/E55gCKZ8lx/image.png',
#    'gender': 'female',
#    'model_url': 's3://d-id-clips-drivers-prod/kayla/zxpG_93n5W/generator.pt',
#    'modified_at': '2023-11-14T08:28:29.881Z',
#    'owner_id': ''},
#   {'presenter_id': 'anita-H_MdjUsV3A',
#    'created_at': '2023-11-14T10:40:30.518Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/anita/H_MdjUsV3A/7PLEdMIW1s/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/anita/H_MdjUsV3A/7PLEdMIW1s/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/anita/H_MdjUsV3A/7PLEdMIW1s/image.png',
#    'gender': 'female',
#    'model_url': 's3://d-id-clips-drivers-prod/anita/H_MdjUsV3A/generator.pt',
#    'modified_at': '2023-11-14T10:40:30.518Z',
#    'owner_id': ''},
#   {'presenter_id': 'anita-UcOoVxD59H',
#    'created_at': '2023-11-14T10:46:25.574Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/anita/UcOoVxD59H/fET_ZHqVWj/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/anita/UcOoVxD59H/fET_ZHqVWj/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/anita/UcOoVxD59H/fET_ZHqVWj/image.png',
#    'gender': 'female',
#    'model_url': 's3://d-id-clips-drivers-prod/anita/UcOoVxD59H/generator.pt',
#    'modified_at': '2023-11-14T10:46:25.574Z',
#    'owner_id': ''},
#   {'presenter_id': 'ella-3SmL1gFLot',
#    'created_at': '2023-11-14T10:53:34.719Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/ella/3SmL1gFLot/w_9MyZlClt/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/ella/3SmL1gFLot/w_9MyZlClt/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/ella/3SmL1gFLot/w_9MyZlClt/image.png',
#    'gender': 'female',
#    'model_url': 's3://d-id-clips-drivers-prod/ella/3SmL1gFLot/generator.pt',
#    'modified_at': '2023-11-14T10:53:34.719Z',
#    'owner_id': ''},
#   {'presenter_id': 'alyssa-Kpjhh2J_rm',
#    'created_at': '2023-11-20T07:53:50.533Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/alyssa/Kpjhh2J_rm/Oa9TBDfWdE/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/alyssa/Kpjhh2J_rm/Oa9TBDfWdE/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/alyssa/Kpjhh2J_rm/Oa9TBDfWdE/image.png',
#    'gender': 'female',
#    'model_url': 's3://d-id-clips-drivers-prod/alyssa/Kpjhh2J_rm/generator.pt',
#    'modified_at': '2023-11-20T07:53:50.533Z',
#    'owner_id': ''},
#   {'presenter_id': 'fiona-Fi5YDeh1YS',
#    'created_at': '2023-11-20T07:59:47.442Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/fiona/Fi5YDeh1YS/Lll2aPJVYj/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/fiona/Fi5YDeh1YS/Lll2aPJVYj/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/fiona/Fi5YDeh1YS/Lll2aPJVYj/image.png',
#    'gender': 'female',
#    'model_url': 's3://d-id-clips-drivers-prod/fiona/Fi5YDeh1YS/generator.pt',
#    'modified_at': '2023-11-20T07:59:47.442Z',
#    'owner_id': ''},
#   {'presenter_id': 'flora-yIQ7chlmeN',
#    'created_at': '2023-11-20T08:01:20.333Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/flora/yIQ7chlmeN/RDwZdZh7nl/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/flora/yIQ7chlmeN/RDwZdZh7nl/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/flora/yIQ7chlmeN/RDwZdZh7nl/image.png',
#    'gender': 'female',
#    'model_url': 's3://d-id-clips-drivers-prod/flora/yIQ7chlmeN/generator.pt',
#    'modified_at': '2023-11-20T08:01:20.333Z',
#    'owner_id': ''},
#   {'presenter_id': 'flora-XAdU5HN6vf',
#    'created_at': '2023-11-20T08:03:42.064Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/flora/XAdU5HN6vf/y6LxXnChum/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/flora/XAdU5HN6vf/y6LxXnChum/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/flora/XAdU5HN6vf/y6LxXnChum/image.png',
#    'gender': 'female',
#    'model_url': 's3://d-id-clips-drivers-prod/flora/XAdU5HN6vf/generator.pt',
#    'modified_at': '2023-11-20T08:03:42.064Z',
#    'owner_id': ''},
#   {'presenter_id': 'arran-esvIrjCjq5',
#    'created_at': '2023-12-10T11:06:44.832Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/arran/esvIrjCjq5/JgPcOxkQeq/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/arran/esvIrjCjq5/JgPcOxkQeq/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/arran/esvIrjCjq5/JgPcOxkQeq/image.png',
#    'gender': 'male',
#    'model_url': 's3://d-id-clips-drivers-prod/arran/esvIrjCjq5/generator.pt',
#    'modified_at': '2023-12-10T11:06:44.832Z',
#    'owner_id': ''},
#   {'presenter_id': 'sophia-ndjDZ_Osqg',
#    'created_at': '2023-12-10T11:07:35.453Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/sophia/ndjDZ_Osqg/5YM8LG217b/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/sophia/ndjDZ_Osqg/5YM8LG217b/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/sophia/ndjDZ_Osqg/5YM8LG217b/image.png',
#    'gender': 'female',
#    'model_url': 's3://d-id-clips-drivers-prod/sophia/ndjDZ_Osqg/generator.pt',
#    'modified_at': '2023-12-10T11:07:35.453Z',
#    'owner_id': ''},
#   {'presenter_id': 'fiona-n3X2_0FF2e',
#    'created_at': '2023-12-10T11:10:11.964Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/fiona/n3X2_0FF2e/dtQMHQu1qO/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/fiona/n3X2_0FF2e/dtQMHQu1qO/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/fiona/n3X2_0FF2e/dtQMHQu1qO/image.png',
#    'gender': 'female',
#    'model_url': 's3://d-id-clips-drivers-prod/fiona/n3X2_0FF2e/generator.pt',
#    'modified_at': '2023-12-10T11:10:11.964Z',
#    'owner_id': ''},
#   {'presenter_id': 'owen-HALXD7yLCN',
#    'created_at': '2023-12-10T11:10:49.510Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/owen/HALXD7yLCN/BDY3gvyM0N/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/owen/HALXD7yLCN/BDY3gvyM0N/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/owen/HALXD7yLCN/BDY3gvyM0N/image.png',
#    'gender': 'male',
#    'model_url': 's3://d-id-clips-drivers-prod/owen/HALXD7yLCN/generator.pt',
#    'modified_at': '2023-12-10T11:10:49.510Z',
#    'owner_id': ''},
#   {'presenter_id': 'diana-tfTP6K9S9u',
#    'created_at': '2023-12-10T11:11:56.840Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/diana/tfTP6K9S9u/6aL7yccFTg/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/diana/tfTP6K9S9u/6aL7yccFTg/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/diana/tfTP6K9S9u/6aL7yccFTg/image.png',
#    'gender': 'female',
#    'model_url': 's3://d-id-clips-drivers-prod/diana/tfTP6K9S9u/generator.pt',
#    'modified_at': '2023-12-10T11:11:56.840Z',
#    'owner_id': ''},
#   {'presenter_id': 'alex-qcVo4GUPOY',
#    'created_at': '2023-12-25T08:53:15.749Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/alex/qcVo4GUPOY/Zn2tuAWme0/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/alex/qcVo4GUPOY/Zn2tuAWme0/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/alex/qcVo4GUPOY/Zn2tuAWme0/image.png',
#    'gender': 'male',
#    'model_url': 's3://d-id-clips-drivers-prod/alex/qcVo4GUPOY/generator.pt',
#    'modified_at': '2023-12-25T08:53:15.749Z',
#    'owner_id': ''},
#   {'presenter_id': 'diana-Ir0x9WlpT4',
#    'created_at': '2023-12-25T09:19:21.300Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/diana/Ir0x9WlpT4/uJX_BBmeQ4/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/diana/Ir0x9WlpT4/uJX_BBmeQ4/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/diana/Ir0x9WlpT4/uJX_BBmeQ4/image.png',
#    'gender': 'female',
#    'model_url': 's3://d-id-clips-drivers-prod/diana/Ir0x9WlpT4/generator.pt',
#    'modified_at': '2023-12-25T09:19:21.301Z',
#    'owner_id': ''},
#   {'presenter_id': 'dylan-E_sy058oXA',
#    'created_at': '2023-12-28T09:44:35.369Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/dylan/E_sy058oXA/_047h5XX_T/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/dylan/E_sy058oXA/_047h5XX_T/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/dylan/E_sy058oXA/_047h5XX_T/image.png',
#    'gender': 'male',
#    'model_url': 's3://d-id-clips-drivers-prod/dylan/E_sy058oXA/generator.pt',
#    'modified_at': '2023-12-28T09:44:35.369Z',
#    'owner_id': ''},
#   {'presenter_id': 'william-FPvBkeR0kv',
#    'created_at': '2023-12-28T11:25:56.672Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/william/FPvBkeR0kv/bAIOAUOG33/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/william/FPvBkeR0kv/bAIOAUOG33/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/william/FPvBkeR0kv/bAIOAUOG33/image.png',
#    'gender': 'male',
#    'model_url': 's3://d-id-clips-drivers-prod/william/FPvBkeR0kv/generator.pt',
#    'modified_at': '2023-12-28T11:25:56.672Z',
#    'owner_id': ''},
#   {'presenter_id': 'alex-Wzfu0JN6HJ',
#    'created_at': '2023-12-28T11:38:28.242Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/alex/Wzfu0JN6HJ/KwxpJTxq1b/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/alex/Wzfu0JN6HJ/KwxpJTxq1b/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/alex/Wzfu0JN6HJ/KwxpJTxq1b/image.png',
#    'gender': 'male',
#    'model_url': 's3://d-id-clips-drivers-prod/alex/Wzfu0JN6HJ/generator.pt',
#    'modified_at': '2023-12-28T11:38:28.243Z',
#    'owner_id': ''},
#   {'presenter_id': 'alex-tv2VbI8lXI',
#    'created_at': '2023-12-28T11:41:28.127Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/alex/tv2VbI8lXI/MeDU8rVHxW/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/alex/tv2VbI8lXI/MeDU8rVHxW/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/alex/tv2VbI8lXI/MeDU8rVHxW/image.png',
#    'gender': 'male',
#    'model_url': 's3://d-id-clips-drivers-prod/alex/tv2VbI8lXI/generator.pt',
#    'modified_at': '2023-12-28T11:41:28.127Z',
#    'owner_id': ''},
#   {'presenter_id': 'alyssa-fIa7P15FTv',
#    'created_at': '2024-01-03T07:51:10.307Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/alyssa/fIa7P15FTv/PWEobsgYC8/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/alyssa/fIa7P15FTv/PWEobsgYC8/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/alyssa/fIa7P15FTv/PWEobsgYC8/image.png',
#    'gender': 'female',
#    'model_url': 's3://d-id-clips-drivers-prod/alyssa/fIa7P15FTv/generator.pt',
#    'modified_at': '2024-01-03T07:51:10.307Z',
#    'owner_id': ''},
#   {'presenter_id': 'kayla-nE41xjTtqs',
#    'created_at': '2024-01-03T09:30:18.538Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/kayla/nE41xjTtqs/uy1GATRh3K/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/kayla/nE41xjTtqs/uy1GATRh3K/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/kayla/nE41xjTtqs/uy1GATRh3K/image.png',
#    'gender': 'female',
#    'model_url': 's3://d-id-clips-drivers-prod/kayla/nE41xjTtqs/generator.pt',
#    'modified_at': '2024-01-03T09:30:18.538Z',
#    'owner_id': ''},
#   {'presenter_id': 'kayla-eroLaZHxe8',
#    'created_at': '2024-01-03T09:30:46.682Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/kayla/eroLaZHxe8/yaPlRdgtN5/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/kayla/eroLaZHxe8/yaPlRdgtN5/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/kayla/eroLaZHxe8/yaPlRdgtN5/image.png',
#    'gender': 'female',
#    'model_url': 's3://d-id-clips-drivers-prod/kayla/eroLaZHxe8/generator.pt',
#    'modified_at': '2024-01-03T09:30:46.682Z',
#    'owner_id': ''},
#   {'presenter_id': 'jaimie-HoDsDwCz3X',
#    'created_at': '2024-01-24T10:11:08.250Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/jaimie/HoDsDwCz3X/vimuEwrzGC/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/jaimie/HoDsDwCz3X/vimuEwrzGC/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/jaimie/HoDsDwCz3X/vimuEwrzGC/image.png',
#    'gender': 'male',
#    'model_url': 's3://d-id-clips-drivers-prod/jaimie/HoDsDwCz3X/generator.pt',
#    'modified_at': '2024-01-24T10:11:08.250Z',
#    'owner_id': ''},
#   {'presenter_id': 'arran-HSSXpUVGi8',
#    'created_at': '2024-01-24T10:16:21.958Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/arran/HSSXpUVGi8/I9beehJGKL/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/arran/HSSXpUVGi8/I9beehJGKL/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/arran/HSSXpUVGi8/I9beehJGKL/image.png',
#    'gender': 'male',
#    'model_url': 's3://d-id-clips-drivers-prod/arran/HSSXpUVGi8/generator.pt',
#    'modified_at': '2024-01-24T10:16:21.958Z',
#    'owner_id': ''},
#   {'presenter_id': 'mary-jah7kZwx3g',
#    'created_at': '2024-01-25T08:35:49.369Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/mary/jah7kZwx3g/2obDeAJiNH/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/mary/jah7kZwx3g/2obDeAJiNH/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/mary/jah7kZwx3g/2obDeAJiNH/image.png',
#    'gender': 'female',
#    'model_url': 's3://d-id-clips-drivers-prod/mary/jah7kZwx3g/generator.pt',
#    'modified_at': '2024-01-25T08:35:49.369Z',
#    'owner_id': ''},
#   {'presenter_id': 'ella-QjarP4rpU6',
#    'created_at': '2024-01-25T08:36:41.380Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/ella/QjarP4rpU6/oCLn1GwOpo/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/ella/QjarP4rpU6/oCLn1GwOpo/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/ella/QjarP4rpU6/oCLn1GwOpo/image.png',
#    'gender': 'female',
#    'model_url': 's3://d-id-clips-drivers-prod/ella/QjarP4rpU6/generator.pt',
#    'modified_at': '2024-01-25T08:36:41.380Z',
#    'owner_id': ''},
#   {'presenter_id': 'jaimie-dVjY0T40xo',
#    'created_at': '2024-01-25T08:36:52.114Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/jaimie/dVjY0T40xo/DLXhGfvcx5/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/jaimie/dVjY0T40xo/DLXhGfvcx5/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/jaimie/dVjY0T40xo/DLXhGfvcx5/image.png',
#    'gender': 'male',
#    'model_url': 's3://d-id-clips-drivers-prod/jaimie/dVjY0T40xo/generator.pt',
#    'modified_at': '2024-01-25T08:36:52.114Z',
#    'owner_id': ''},
#   {'presenter_id': 'darren-RYscOXmp8t',
#    'created_at': '2024-01-25T08:39:51.677Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/darren/RYscOXmp8t/CtDjn3POSq/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/darren/RYscOXmp8t/CtDjn3POSq/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/darren/RYscOXmp8t/CtDjn3POSq/image.png',
#    'gender': 'male',
#    'model_url': 's3://d-id-clips-drivers-prod/darren/RYscOXmp8t/generator.pt',
#    'modified_at': '2024-01-25T08:39:51.677Z',
#    'owner_id': ''},
#   {'presenter_id': 'fiona-KoeYgsGmIj',
#    'created_at': '2024-01-25T08:41:06.818Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/fiona/KoeYgsGmIj/XWUcHkVH3Z/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/fiona/KoeYgsGmIj/XWUcHkVH3Z/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/fiona/KoeYgsGmIj/XWUcHkVH3Z/image.png',
#    'gender': 'female',
#    'model_url': 's3://d-id-clips-drivers-prod/fiona/KoeYgsGmIj/generator.pt',
#    'modified_at': '2024-01-25T08:41:06.818Z',
#    'owner_id': ''},
#   {'presenter_id': 'mary-d3srfuXaAk',
#    'created_at': '2024-01-25T08:41:40.112Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/mary/d3srfuXaAk/_U617Y7LB9/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/mary/d3srfuXaAk/_U617Y7LB9/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/mary/d3srfuXaAk/_U617Y7LB9/image.png',
#    'gender': 'female',
#    'model_url': 's3://d-id-clips-drivers-prod/mary/d3srfuXaAk/generator.pt',
#    'modified_at': '2024-01-25T08:41:40.112Z',
#    'owner_id': ''},
#   {'presenter_id': 'darren-WbmWyG0cSZ',
#    'created_at': '2024-01-25T08:44:14.091Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/darren/WbmWyG0cSZ/GYfz0eIF5y/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/darren/WbmWyG0cSZ/GYfz0eIF5y/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/darren/WbmWyG0cSZ/GYfz0eIF5y/image.png',
#    'gender': 'male',
#    'model_url': 's3://d-id-clips-drivers-prod/darren/WbmWyG0cSZ/generator.pt',
#    'modified_at': '2024-01-25T08:44:14.091Z',
#    'owner_id': ''},
#   {'presenter_id': 'sophia-kEFEd7dZAh',
#    'created_at': '2024-01-25T12:15:46.839Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/sophia/kEFEd7dZAh/JtQoGEmJyC/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/sophia/kEFEd7dZAh/JtQoGEmJyC/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/sophia/kEFEd7dZAh/JtQoGEmJyC/image.png',
#    'gender': 'female',
#    'model_url': 's3://d-id-clips-drivers-prod/sophia/kEFEd7dZAh/generator.pt',
#    'modified_at': '2024-01-25T12:15:46.839Z',
#    'owner_id': ''},
#   {'presenter_id': 'owen-WajdX1Hx55',
#    'created_at': '2024-01-25T12:17:09.998Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/owen/WajdX1Hx55/YDBb1QuA_B/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/owen/WajdX1Hx55/YDBb1QuA_B/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/owen/WajdX1Hx55/YDBb1QuA_B/image.png',
#    'gender': 'male',
#    'model_url': 's3://d-id-clips-drivers-prod/owen/WajdX1Hx55/generator.pt',
#    'modified_at': '2024-01-25T12:17:09.998Z',
#    'owner_id': ''},
#   {'presenter_id': 'owen-tI5q5OPEbX',
#    'created_at': '2024-01-25T12:20:58.557Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/owen/tI5q5OPEbX/DTee2K4ZiI/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/owen/tI5q5OPEbX/DTee2K4ZiI/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/owen/tI5q5OPEbX/DTee2K4ZiI/image.png',
#    'gender': 'male',
#    'model_url': 's3://d-id-clips-drivers-prod/owen/tI5q5OPEbX/generator.pt',
#    'modified_at': '2024-01-25T12:20:58.557Z',
#    'owner_id': ''},
#   {'presenter_id': 'darren-i8c1QVeEdf',
#    'created_at': '2024-01-28T10:51:16.034Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/darren/i8c1QVeEdf/MEqSdRBvfD/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/darren/i8c1QVeEdf/MEqSdRBvfD/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/darren/i8c1QVeEdf/MEqSdRBvfD/image.png',
#    'gender': 'male',
#    'model_url': 's3://d-id-clips-drivers-prod/darren/i8c1QVeEdf/generator.pt',
#    'modified_at': '2024-01-28T10:51:16.034Z',
#    'owner_id': ''},
#   {'presenter_id': 'william-qE4P1OFtWM',
#    'created_at': '2024-01-29T09:26:00.566Z',
#    'thumbnail_url': 'https://clips-presenters.d-id.com/william/qE4P1OFtWM/Lc2cQ93AYR/thumbnail.png',
#    'preview_url': 'https://clips-presenters.d-id.com/william/qE4P1OFtWM/Lc2cQ93AYR/preview.mp4',
#    'image_url': 'https://clips-presenters.d-id.com/william/qE4P1OFtWM/Lc2cQ93AYR/image.png',
#    'gender': 'male',
#    'model_url': 's3://d-id-clips-drivers-prod/william/qE4P1OFtWM/generator.pt',
#    'modified_at': '2024-01-29T09:26:00.566Z',
#    'owner_id': ''}]}

# %% [markdown]
# ###Voices

# %%
import requests

url = "https://api.d-id.com/tts/voices?provider=microsoft"

D_iD_API_KEY=os.getenv("D_iD_API_KEY")

headers = {
    "accept": "application/json",
    "authorization": D_iD_API_KEY
}

response = requests.get(url, headers=headers)

response.json()
# Out:
# [{'id': 'af-ZA-AdriNeural',
#   'name': 'Adri',
#   'gender': 'female',
#   'locale': 'af-ZA',
#   'language': 'Afrikaans (South Africa)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'af-ZA-WillemNeural',
#   'name': 'Willem',
#   'gender': 'male',
#   'locale': 'af-ZA',
#   'language': 'Afrikaans (South Africa)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'am-ET-MekdesNeural',
#   'name': 'Mekdes',
#   'gender': 'female',
#   'locale': 'am-ET',
#   'language': 'Amharic (Ethiopia)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'am-ET-AmehaNeural',
#   'name': 'Ameha',
#   'gender': 'male',
#   'locale': 'am-ET',
#   'language': 'Amharic (Ethiopia)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ar-AE-FatimaNeural',
#   'name': 'Fatima',
#   'gender': 'female',
#   'locale': 'ar-AE',
#   'language': 'Arabic (United Arab Emirates)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ar-AE-HamdanNeural',
#   'name': 'Hamdan',
#   'gender': 'male',
#   'locale': 'ar-AE',
#   'language': 'Arabic (United Arab Emirates)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ar-BH-LailaNeural',
#   'name': 'Laila',
#   'gender': 'female',
#   'locale': 'ar-BH',
#   'language': 'Arabic (Bahrain)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ar-BH-AliNeural',
#   'name': 'Ali',
#   'gender': 'male',
#   'locale': 'ar-BH',
#   'language': 'Arabic (Bahrain)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ar-DZ-AminaNeural',
#   'name': 'Amina',
#   'gender': 'female',
#   'locale': 'ar-DZ',
#   'language': 'Arabic (Algeria)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ar-DZ-IsmaelNeural',
#   'name': 'Ismael',
#   'gender': 'male',
#   'locale': 'ar-DZ',
#   'language': 'Arabic (Algeria)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ar-EG-SalmaNeural',
#   'name': 'Salma',
#   'gender': 'female',
#   'locale': 'ar-EG',
#   'language': 'Arabic (Egypt)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ar-EG-ShakirNeural',
#   'name': 'Shakir',
#   'gender': 'male',
#   'locale': 'ar-EG',
#   'language': 'Arabic (Egypt)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ar-EG-Hoda',
#   'name': 'Hoda',
#   'gender': 'female',
#   'locale': 'ar-EG',
#   'language': 'Arabic (Egypt)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ar-IQ-RanaNeural',
#   'name': 'Rana',
#   'gender': 'female',
#   'locale': 'ar-IQ',
#   'language': 'Arabic (Iraq)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ar-IQ-BasselNeural',
#   'name': 'Bassel',
#   'gender': 'male',
#   'locale': 'ar-IQ',
#   'language': 'Arabic (Iraq)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ar-JO-SanaNeural',
#   'name': 'Sana',
#   'gender': 'female',
#   'locale': 'ar-JO',
#   'language': 'Arabic (Jordan)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ar-JO-TaimNeural',
#   'name': 'Taim',
#   'gender': 'male',
#   'locale': 'ar-JO',
#   'language': 'Arabic (Jordan)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ar-KW-NouraNeural',
#   'name': 'Noura',
#   'gender': 'female',
#   'locale': 'ar-KW',
#   'language': 'Arabic (Kuwait)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ar-KW-FahedNeural',
#   'name': 'Fahed',
#   'gender': 'male',
#   'locale': 'ar-KW',
#   'language': 'Arabic (Kuwait)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ar-LB-LaylaNeural',
#   'name': 'Layla',
#   'gender': 'female',
#   'locale': 'ar-LB',
#   'language': 'Arabic (Lebanon)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ar-LB-RamiNeural',
#   'name': 'Rami',
#   'gender': 'male',
#   'locale': 'ar-LB',
#   'language': 'Arabic (Lebanon)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ar-LY-ImanNeural',
#   'name': 'Iman',
#   'gender': 'female',
#   'locale': 'ar-LY',
#   'language': 'Arabic (Libya)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ar-LY-OmarNeural',
#   'name': 'Omar',
#   'gender': 'male',
#   'locale': 'ar-LY',
#   'language': 'Arabic (Libya)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ar-MA-MounaNeural',
#   'name': 'Mouna',
#   'gender': 'female',
#   'locale': 'ar-MA',
#   'language': 'Arabic (Morocco)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ar-MA-JamalNeural',
#   'name': 'Jamal',
#   'gender': 'male',
#   'locale': 'ar-MA',
#   'language': 'Arabic (Morocco)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ar-OM-AyshaNeural',
#   'name': 'Aysha',
#   'gender': 'female',
#   'locale': 'ar-OM',
#   'language': 'Arabic (Oman)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ar-OM-AbdullahNeural',
#   'name': 'Abdullah',
#   'gender': 'male',
#   'locale': 'ar-OM',
#   'language': 'Arabic (Oman)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ar-QA-AmalNeural',
#   'name': 'Amal',
#   'gender': 'female',
#   'locale': 'ar-QA',
#   'language': 'Arabic (Qatar)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ar-QA-MoazNeural',
#   'name': 'Moaz',
#   'gender': 'male',
#   'locale': 'ar-QA',
#   'language': 'Arabic (Qatar)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ar-SA-ZariyahNeural',
#   'name': 'Zariyah',
#   'gender': 'female',
#   'locale': 'ar-SA',
#   'language': 'Arabic (Saudi Arabia)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ar-SA-HamedNeural',
#   'name': 'Hamed',
#   'gender': 'male',
#   'locale': 'ar-SA',
#   'language': 'Arabic (Saudi Arabia)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ar-SA-Naayf',
#   'name': 'Naayf',
#   'gender': 'male',
#   'locale': 'ar-SA',
#   'language': 'Arabic (Saudi Arabia)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ar-SY-AmanyNeural',
#   'name': 'Amany',
#   'gender': 'female',
#   'locale': 'ar-SY',
#   'language': 'Arabic (Syria)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ar-SY-LaithNeural',
#   'name': 'Laith',
#   'gender': 'male',
#   'locale': 'ar-SY',
#   'language': 'Arabic (Syria)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ar-TN-ReemNeural',
#   'name': 'Reem',
#   'gender': 'female',
#   'locale': 'ar-TN',
#   'language': 'Arabic (Tunisia)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ar-TN-HediNeural',
#   'name': 'Hedi',
#   'gender': 'male',
#   'locale': 'ar-TN',
#   'language': 'Arabic (Tunisia)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ar-YE-MaryamNeural',
#   'name': 'Maryam',
#   'gender': 'female',
#   'locale': 'ar-YE',
#   'language': 'Arabic (Yemen)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ar-YE-SalehNeural',
#   'name': 'Saleh',
#   'gender': 'male',
#   'locale': 'ar-YE',
#   'language': 'Arabic (Yemen)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'az-AZ-BanuNeural',
#   'name': 'Banu',
#   'gender': 'female',
#   'locale': 'az-AZ',
#   'language': 'Azerbaijani (Latin, Azerbaijan)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'az-AZ-BabekNeural',
#   'name': 'Babek',
#   'gender': 'male',
#   'locale': 'az-AZ',
#   'language': 'Azerbaijani (Latin, Azerbaijan)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'bg-BG-KalinaNeural',
#   'name': 'Kalina',
#   'gender': 'female',
#   'locale': 'bg-BG',
#   'language': 'Bulgarian (Bulgaria)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'bg-BG-BorislavNeural',
#   'name': 'Borislav',
#   'gender': 'male',
#   'locale': 'bg-BG',
#   'language': 'Bulgarian (Bulgaria)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'bg-BG-Ivan',
#   'name': 'Ivan',
#   'gender': 'male',
#   'locale': 'bg-BG',
#   'language': 'Bulgarian (Bulgaria)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'bn-BD-NabanitaNeural',
#   'name': 'Nabanita',
#   'gender': 'female',
#   'locale': 'bn-BD',
#   'language': 'Bangla (Bangladesh)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'bn-BD-PradeepNeural',
#   'name': 'Pradeep',
#   'gender': 'male',
#   'locale': 'bn-BD',
#   'language': 'Bangla (Bangladesh)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'bn-IN-TanishaaNeural',
#   'name': 'Tanishaa',
#   'gender': 'female',
#   'locale': 'bn-IN',
#   'language': 'Bengali (India)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'bn-IN-BashkarNeural',
#   'name': 'Bashkar',
#   'gender': 'male',
#   'locale': 'bn-IN',
#   'language': 'Bengali (India)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'bs-BA-VesnaNeural',
#   'name': 'Vesna',
#   'gender': 'female',
#   'locale': 'bs-BA',
#   'language': 'Bosnian (Bosnia and Herzegovina)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'bs-BA-GoranNeural',
#   'name': 'Goran',
#   'gender': 'male',
#   'locale': 'bs-BA',
#   'language': 'Bosnian (Bosnia and Herzegovina)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ca-ES-JoanaNeural',
#   'name': 'Joana',
#   'gender': 'female',
#   'locale': 'ca-ES',
#   'language': 'Catalan (Spain)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ca-ES-EnricNeural',
#   'name': 'Enric',
#   'gender': 'male',
#   'locale': 'ca-ES',
#   'language': 'Catalan (Spain)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ca-ES-AlbaNeural',
#   'name': 'Alba',
#   'gender': 'female',
#   'locale': 'ca-ES',
#   'language': 'Catalan (Spain)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ca-ES-HerenaRUS',
#   'name': 'Herena',
#   'gender': 'female',
#   'locale': 'ca-ES',
#   'language': 'Catalan (Spain)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'cs-CZ-VlastaNeural',
#   'name': 'Vlasta',
#   'gender': 'female',
#   'locale': 'cs-CZ',
#   'language': 'Czech (Czechia)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'cs-CZ-AntoninNeural',
#   'name': 'Antonin',
#   'gender': 'male',
#   'locale': 'cs-CZ',
#   'language': 'Czech (Czechia)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'cs-CZ-Jakub',
#   'name': 'Jakub',
#   'gender': 'male',
#   'locale': 'cs-CZ',
#   'language': 'Czech (Czechia)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'cy-GB-NiaNeural',
#   'name': 'Nia',
#   'gender': 'female',
#   'locale': 'cy-GB',
#   'language': 'Welsh (United Kingdom)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'cy-GB-AledNeural',
#   'name': 'Aled',
#   'gender': 'male',
#   'locale': 'cy-GB',
#   'language': 'Welsh (United Kingdom)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'da-DK-ChristelNeural',
#   'name': 'Christel',
#   'gender': 'female',
#   'locale': 'da-DK',
#   'language': 'Danish (Denmark)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'da-DK-JeppeNeural',
#   'name': 'Jeppe',
#   'gender': 'male',
#   'locale': 'da-DK',
#   'language': 'Danish (Denmark)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'da-DK-HelleRUS',
#   'name': 'Helle',
#   'gender': 'female',
#   'locale': 'da-DK',
#   'language': 'Danish (Denmark)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'de-AT-IngridNeural',
#   'name': 'Ingrid',
#   'gender': 'female',
#   'locale': 'de-AT',
#   'language': 'German (Austria)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'de-AT-JonasNeural',
#   'name': 'Jonas',
#   'gender': 'male',
#   'locale': 'de-AT',
#   'language': 'German (Austria)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'de-AT-Michael',
#   'name': 'Michael',
#   'gender': 'male',
#   'locale': 'de-AT',
#   'language': 'German (Austria)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'de-CH-LeniNeural',
#   'name': 'Leni',
#   'gender': 'female',
#   'locale': 'de-CH',
#   'language': 'German (Switzerland)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'de-CH-JanNeural',
#   'name': 'Jan',
#   'gender': 'male',
#   'locale': 'de-CH',
#   'language': 'German (Switzerland)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'de-CH-Karsten',
#   'name': 'Karsten',
#   'gender': 'male',
#   'locale': 'de-CH',
#   'language': 'German (Switzerland)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'de-DE-KatjaNeural',
#   'name': 'Katja',
#   'gender': 'female',
#   'locale': 'de-DE',
#   'language': 'German (Germany)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'de-DE-ConradNeural',
#   'name': 'Conrad',
#   'gender': 'male',
#   'locale': 'de-DE',
#   'language': 'German (Germany)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'de-DE-AmalaNeural',
#   'name': 'Amala',
#   'gender': 'female',
#   'locale': 'de-DE',
#   'language': 'German (Germany)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'de-DE-BerndNeural',
#   'name': 'Bernd',
#   'gender': 'male',
#   'locale': 'de-DE',
#   'language': 'German (Germany)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'de-DE-ChristophNeural',
#   'name': 'Christoph',
#   'gender': 'male',
#   'locale': 'de-DE',
#   'language': 'German (Germany)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'de-DE-ElkeNeural',
#   'name': 'Elke',
#   'gender': 'female',
#   'locale': 'de-DE',
#   'language': 'German (Germany)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'de-DE-GiselaNeural',
#   'name': 'Gisela',
#   'gender': 'female',
#   'locale': 'de-DE',
#   'language': 'German (Germany)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'de-DE-KasperNeural',
#   'name': 'Kasper',
#   'gender': 'male',
#   'locale': 'de-DE',
#   'language': 'German (Germany)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'de-DE-KillianNeural',
#   'name': 'Killian',
#   'gender': 'male',
#   'locale': 'de-DE',
#   'language': 'German (Germany)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'de-DE-KlarissaNeural',
#   'name': 'Klarissa',
#   'gender': 'female',
#   'locale': 'de-DE',
#   'language': 'German (Germany)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'de-DE-KlausNeural',
#   'name': 'Klaus',
#   'gender': 'male',
#   'locale': 'de-DE',
#   'language': 'German (Germany)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'de-DE-LouisaNeural',
#   'name': 'Louisa',
#   'gender': 'female',
#   'locale': 'de-DE',
#   'language': 'German (Germany)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'de-DE-MajaNeural',
#   'name': 'Maja',
#   'gender': 'female',
#   'locale': 'de-DE',
#   'language': 'German (Germany)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'de-DE-RalfNeural',
#   'name': 'Ralf',
#   'gender': 'male',
#   'locale': 'de-DE',
#   'language': 'German (Germany)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'de-DE-TanjaNeural',
#   'name': 'Tanja',
#   'gender': 'female',
#   'locale': 'de-DE',
#   'language': 'German (Germany)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'de-DE-HeddaRUS',
#   'name': 'Hedda',
#   'gender': 'female',
#   'locale': 'de-DE',
#   'language': 'German (Germany)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'de-DE-Stefan',
#   'name': 'Stefan',
#   'gender': 'male',
#   'locale': 'de-DE',
#   'language': 'German (Germany)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'el-GR-AthinaNeural',
#   'name': 'Athina',
#   'gender': 'female',
#   'locale': 'el-GR',
#   'language': 'Greek (Greece)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'el-GR-NestorasNeural',
#   'name': 'Nestoras',
#   'gender': 'male',
#   'locale': 'el-GR',
#   'language': 'Greek (Greece)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'el-GR-Stefanos',
#   'name': 'Stefanos',
#   'gender': 'male',
#   'locale': 'el-GR',
#   'language': 'Greek (Greece)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-AU-NatashaNeural',
#   'name': 'Natasha',
#   'gender': 'female',
#   'locale': 'en-AU',
#   'language': 'English (Australia)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-AU-WilliamNeural',
#   'name': 'William',
#   'gender': 'male',
#   'locale': 'en-AU',
#   'language': 'English (Australia)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-AU-AnnetteNeural',
#   'name': 'Annette',
#   'gender': 'female',
#   'locale': 'en-AU',
#   'language': 'English (Australia)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-AU-CarlyNeural',
#   'name': 'Carly',
#   'gender': 'female',
#   'locale': 'en-AU',
#   'language': 'English (Australia)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-AU-DarrenNeural',
#   'name': 'Darren',
#   'gender': 'male',
#   'locale': 'en-AU',
#   'language': 'English (Australia)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-AU-DuncanNeural',
#   'name': 'Duncan',
#   'gender': 'male',
#   'locale': 'en-AU',
#   'language': 'English (Australia)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-AU-ElsieNeural',
#   'name': 'Elsie',
#   'gender': 'female',
#   'locale': 'en-AU',
#   'language': 'English (Australia)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-AU-FreyaNeural',
#   'name': 'Freya',
#   'gender': 'female',
#   'locale': 'en-AU',
#   'language': 'English (Australia)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-AU-JoanneNeural',
#   'name': 'Joanne',
#   'gender': 'female',
#   'locale': 'en-AU',
#   'language': 'English (Australia)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-AU-KenNeural',
#   'name': 'Ken',
#   'gender': 'male',
#   'locale': 'en-AU',
#   'language': 'English (Australia)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-AU-KimNeural',
#   'name': 'Kim',
#   'gender': 'female',
#   'locale': 'en-AU',
#   'language': 'English (Australia)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-AU-NeilNeural',
#   'name': 'Neil',
#   'gender': 'male',
#   'locale': 'en-AU',
#   'language': 'English (Australia)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-AU-TimNeural',
#   'name': 'Tim',
#   'gender': 'male',
#   'locale': 'en-AU',
#   'language': 'English (Australia)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-AU-TinaNeural',
#   'name': 'Tina',
#   'gender': 'female',
#   'locale': 'en-AU',
#   'language': 'English (Australia)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-AU-Catherine',
#   'name': 'Catherine',
#   'gender': 'female',
#   'locale': 'en-AU',
#   'language': 'English (Australia)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-AU-HayleyRUS',
#   'name': 'Hayley',
#   'gender': 'female',
#   'locale': 'en-AU',
#   'language': 'English (Australia)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-CA-ClaraNeural',
#   'name': 'Clara',
#   'gender': 'female',
#   'locale': 'en-CA',
#   'language': 'English (Canada)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-CA-LiamNeural',
#   'name': 'Liam',
#   'gender': 'male',
#   'locale': 'en-CA',
#   'language': 'English (Canada)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-CA-HeatherRUS',
#   'name': 'Heather',
#   'gender': 'female',
#   'locale': 'en-CA',
#   'language': 'English (Canada)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-CA-Linda',
#   'name': 'Linda',
#   'gender': 'female',
#   'locale': 'en-CA',
#   'language': 'English (Canada)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-GB-SoniaNeural',
#   'name': 'Sonia',
#   'gender': 'female',
#   'locale': 'en-GB',
#   'language': 'English (United Kingdom)',
#   'access': 'public',
#   'provider': 'microsoft',
#   'styles': ['cheerful', 'sad']},
#  {'id': 'en-GB-RyanNeural',
#   'name': 'Ryan',
#   'gender': 'male',
#   'locale': 'en-GB',
#   'language': 'English (United Kingdom)',
#   'access': 'public',
#   'provider': 'microsoft',
#   'styles': ['cheerful', 'chat']},
#  {'id': 'en-GB-LibbyNeural',
#   'name': 'Libby',
#   'gender': 'female',
#   'locale': 'en-GB',
#   'language': 'English (United Kingdom)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-GB-AbbiNeural',
#   'name': 'Abbi',
#   'gender': 'female',
#   'locale': 'en-GB',
#   'language': 'English (United Kingdom)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-GB-AlfieNeural',
#   'name': 'Alfie',
#   'gender': 'male',
#   'locale': 'en-GB',
#   'language': 'English (United Kingdom)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-GB-BellaNeural',
#   'name': 'Bella',
#   'gender': 'female',
#   'locale': 'en-GB',
#   'language': 'English (United Kingdom)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-GB-ElliotNeural',
#   'name': 'Elliot',
#   'gender': 'male',
#   'locale': 'en-GB',
#   'language': 'English (United Kingdom)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-GB-EthanNeural',
#   'name': 'Ethan',
#   'gender': 'male',
#   'locale': 'en-GB',
#   'language': 'English (United Kingdom)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-GB-HollieNeural',
#   'name': 'Hollie',
#   'gender': 'female',
#   'locale': 'en-GB',
#   'language': 'English (United Kingdom)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-GB-MaisieNeural',
#   'name': 'Maisie',
#   'gender': 'female',
#   'locale': 'en-GB',
#   'language': 'English (United Kingdom)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-GB-NoahNeural',
#   'name': 'Noah',
#   'gender': 'male',
#   'locale': 'en-GB',
#   'language': 'English (United Kingdom)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-GB-OliverNeural',
#   'name': 'Oliver',
#   'gender': 'male',
#   'locale': 'en-GB',
#   'language': 'English (United Kingdom)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-GB-OliviaNeural',
#   'name': 'Olivia',
#   'gender': 'female',
#   'locale': 'en-GB',
#   'language': 'English (United Kingdom)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-GB-ThomasNeural',
#   'name': 'Thomas',
#   'gender': 'male',
#   'locale': 'en-GB',
#   'language': 'English (United Kingdom)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-GB-MiaNeural',
#   'name': 'Mia',
#   'gender': 'female',
#   'locale': 'en-GB',
#   'language': 'English (United Kingdom)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-GB-George',
#   'name': 'George',
#   'gender': 'male',
#   'locale': 'en-GB',
#   'language': 'English (United Kingdom)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-GB-HazelRUS',
#   'name': 'Hazel',
#   'gender': 'female',
#   'locale': 'en-GB',
#   'language': 'English (United Kingdom)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-GB-Susan',
#   'name': 'Susan',
#   'gender': 'female',
#   'locale': 'en-GB',
#   'language': 'English (United Kingdom)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-HK-YanNeural',
#   'name': 'Yan',
#   'gender': 'female',
#   'locale': 'en-HK',
#   'language': 'English (Hong Kong SAR)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-HK-SamNeural',
#   'name': 'Sam',
#   'gender': 'male',
#   'locale': 'en-HK',
#   'language': 'English (Hong Kong SAR)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-IE-EmilyNeural',
#   'name': 'Emily',
#   'gender': 'female',
#   'locale': 'en-IE',
#   'language': 'English (Ireland)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-IE-ConnorNeural',
#   'name': 'Connor',
#   'gender': 'male',
#   'locale': 'en-IE',
#   'language': 'English (Ireland)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-IE-Sean',
#   'name': 'Sean',
#   'gender': 'male',
#   'locale': 'en-IE',
#   'language': 'English (Ireland)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-IN-NeerjaNeural',
#   'name': 'Neerja',
#   'gender': 'female',
#   'locale': 'en-IN',
#   'language': 'English (India)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-IN-PrabhatNeural',
#   'name': 'Prabhat',
#   'gender': 'male',
#   'locale': 'en-IN',
#   'language': 'English (India)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-IN-Heera',
#   'name': 'Heera',
#   'gender': 'female',
#   'locale': 'en-IN',
#   'language': 'English (India)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-IN-PriyaRUS',
#   'name': 'Priya',
#   'gender': 'female',
#   'locale': 'en-IN',
#   'language': 'English (India)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-IN-Ravi',
#   'name': 'Ravi',
#   'gender': 'male',
#   'locale': 'en-IN',
#   'language': 'English (India)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-KE-AsiliaNeural',
#   'name': 'Asilia',
#   'gender': 'female',
#   'locale': 'en-KE',
#   'language': 'English (Kenya)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-KE-ChilembaNeural',
#   'name': 'Chilemba',
#   'gender': 'male',
#   'locale': 'en-KE',
#   'language': 'English (Kenya)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-NG-EzinneNeural',
#   'name': 'Ezinne',
#   'gender': 'female',
#   'locale': 'en-NG',
#   'language': 'English (Nigeria)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-NG-AbeoNeural',
#   'name': 'Abeo',
#   'gender': 'male',
#   'locale': 'en-NG',
#   'language': 'English (Nigeria)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-NZ-MollyNeural',
#   'name': 'Molly',
#   'gender': 'female',
#   'locale': 'en-NZ',
#   'language': 'English (New Zealand)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-NZ-MitchellNeural',
#   'name': 'Mitchell',
#   'gender': 'male',
#   'locale': 'en-NZ',
#   'language': 'English (New Zealand)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-PH-RosaNeural',
#   'name': 'Rosa',
#   'gender': 'female',
#   'locale': 'en-PH',
#   'language': 'English (Philippines)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-PH-JamesNeural',
#   'name': 'James',
#   'gender': 'male',
#   'locale': 'en-PH',
#   'language': 'English (Philippines)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-SG-LunaNeural',
#   'name': 'Luna',
#   'gender': 'female',
#   'locale': 'en-SG',
#   'language': 'English (Singapore)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-SG-WayneNeural',
#   'name': 'Wayne',
#   'gender': 'male',
#   'locale': 'en-SG',
#   'language': 'English (Singapore)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-TZ-ImaniNeural',
#   'name': 'Imani',
#   'gender': 'female',
#   'locale': 'en-TZ',
#   'language': 'English (Tanzania)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-TZ-ElimuNeural',
#   'name': 'Elimu',
#   'gender': 'male',
#   'locale': 'en-TZ',
#   'language': 'English (Tanzania)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-US-AvaNeural',
#   'name': 'Ava',
#   'gender': 'female',
#   'locale': 'en-US',
#   'language': 'English (United States)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-US-AndrewNeural',
#   'name': 'Andrew',
#   'gender': 'male',
#   'locale': 'en-US',
#   'language': 'English (United States)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-US-EmmaNeural',
#   'name': 'Emma',
#   'gender': 'female',
#   'locale': 'en-US',
#   'language': 'English (United States)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-US-BrianNeural',
#   'name': 'Brian',
#   'gender': 'male',
#   'locale': 'en-US',
#   'language': 'English (United States)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-US-JennyNeural',
#   'name': 'Jenny',
#   'gender': 'female',
#   'locale': 'en-US',
#   'language': 'English (United States)',
#   'access': 'public',
#   'provider': 'microsoft',
#   'styles': ['assistant',
#    'chat',
#    'customerservice',
#    'newscast',
#    'angry',
#    'cheerful',
#    'sad',
#    'excited',
#    'friendly',
#    'terrified',
#    'shouting',
#    'unfriendly',
#    'whispering',
#    'hopeful']},
#  {'id': 'en-US-GuyNeural',
#   'name': 'Guy',
#   'gender': 'male',
#   'locale': 'en-US',
#   'language': 'English (United States)',
#   'access': 'public',
#   'provider': 'microsoft',
#   'styles': ['newscast',
#    'angry',
#    'cheerful',
#    'sad',
#    'excited',
#    'friendly',
#    'terrified',
#    'shouting',
#    'unfriendly',
#    'whispering',
#    'hopeful']},
#  {'id': 'en-US-AriaNeural',
#   'name': 'Aria',
#   'gender': 'female',
#   'locale': 'en-US',
#   'language': 'English (United States)',
#   'access': 'public',
#   'provider': 'microsoft',
#   'styles': ['chat',
#    'customerservice',
#    'narration-professional',
#    'newscast-casual',
#    'newscast-formal',
#    'cheerful',
#    'empathetic',
#    'angry',
#    'sad',
#    'excited',
#    'friendly',
#    'terrified',
#    'shouting',
#    'unfriendly',
#    'whispering',
#    'hopeful']},
#  {'id': 'en-US-DavisNeural',
#   'name': 'Davis',
#   'gender': 'male',
#   'locale': 'en-US',
#   'language': 'English (United States)',
#   'access': 'public',
#   'provider': 'microsoft',
#   'styles': ['chat',
#    'angry',
#    'cheerful',
#    'excited',
#    'friendly',
#    'hopeful',
#    'sad',
#    'shouting',
#    'terrified',
#    'unfriendly',
#    'whispering']},
#  {'id': 'en-US-JaneNeural',
#   'name': 'Jane',
#   'gender': 'female',
#   'locale': 'en-US',
#   'language': 'English (United States)',
#   'access': 'public',
#   'provider': 'microsoft',
#   'styles': ['angry',
#    'cheerful',
#    'excited',
#    'friendly',
#    'hopeful',
#    'sad',
#    'shouting',
#    'terrified',
#    'unfriendly',
#    'whispering']},
#  {'id': 'en-US-JasonNeural',
#   'name': 'Jason',
#   'gender': 'male',
#   'locale': 'en-US',
#   'language': 'English (United States)',
#   'access': 'public',
#   'provider': 'microsoft',
#   'styles': ['angry',
#    'cheerful',
#    'excited',
#    'friendly',
#    'hopeful',
#    'sad',
#    'shouting',
#    'terrified',
#    'unfriendly',
#    'whispering']},
#  {'id': 'en-US-SaraNeural',
#   'name': 'Sara',
#   'gender': 'female',
#   'locale': 'en-US',
#   'language': 'English (United States)',
#   'access': 'public',
#   'provider': 'microsoft',
#   'styles': ['angry',
#    'cheerful',
#    'excited',
#    'friendly',
#    'hopeful',
#    'sad',
#    'shouting',
#    'terrified',
#    'unfriendly',
#    'whispering']},
#  {'id': 'en-US-TonyNeural',
#   'name': 'Tony',
#   'gender': 'male',
#   'locale': 'en-US',
#   'language': 'English (United States)',
#   'access': 'public',
#   'provider': 'microsoft',
#   'styles': ['angry',
#    'cheerful',
#    'excited',
#    'friendly',
#    'hopeful',
#    'sad',
#    'shouting',
#    'terrified',
#    'unfriendly',
#    'whispering']},
#  {'id': 'en-US-NancyNeural',
#   'name': 'Nancy',
#   'gender': 'female',
#   'locale': 'en-US',
#   'language': 'English (United States)',
#   'access': 'public',
#   'provider': 'microsoft',
#   'styles': ['angry',
#    'cheerful',
#    'excited',
#    'friendly',
#    'hopeful',
#    'sad',
#    'shouting',
#    'terrified',
#    'unfriendly',
#    'whispering']},
#  {'id': 'en-US-AmberNeural',
#   'name': 'Amber',
#   'gender': 'female',
#   'locale': 'en-US',
#   'language': 'English (United States)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-US-AnaNeural',
#   'name': 'Ana',
#   'gender': 'female',
#   'locale': 'en-US',
#   'language': 'English (United States)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-US-AndrewMultilingualNeural',
#   'name': 'AndrewMultilingualNeural',
#   'gender': 'male',
#   'locale': 'en-US',
#   'language': 'English (United States)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-US-AshleyNeural',
#   'name': 'Ashley',
#   'gender': 'female',
#   'locale': 'en-US',
#   'language': 'English (United States)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-US-AvaMultilingualNeural',
#   'name': 'AvaMultilingualNeural',
#   'gender': 'female',
#   'locale': 'en-US',
#   'language': 'English (United States)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-US-BrandonNeural',
#   'name': 'Brandon',
#   'gender': 'male',
#   'locale': 'en-US',
#   'language': 'English (United States)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-US-BrianMultilingualNeural',
#   'name': 'BrianMultilingualNeural',
#   'gender': 'male',
#   'locale': 'en-US',
#   'language': 'English (United States)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-US-ChristopherNeural',
#   'name': 'Christopher',
#   'gender': 'male',
#   'locale': 'en-US',
#   'language': 'English (United States)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-US-CoraNeural',
#   'name': 'Cora',
#   'gender': 'female',
#   'locale': 'en-US',
#   'language': 'English (United States)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-US-ElizabethNeural',
#   'name': 'Elizabeth',
#   'gender': 'female',
#   'locale': 'en-US',
#   'language': 'English (United States)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-US-EmmaMultilingualNeural',
#   'name': 'EmmaMultilingualNeural',
#   'gender': 'female',
#   'locale': 'en-US',
#   'language': 'English (United States)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-US-EricNeural',
#   'name': 'Eric',
#   'gender': 'male',
#   'locale': 'en-US',
#   'language': 'English (United States)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-US-JacobNeural',
#   'name': 'Jacob',
#   'gender': 'male',
#   'locale': 'en-US',
#   'language': 'English (United States)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-US-JennyMultilingualNeural',
#   'name': 'Jenny Multilingual',
#   'gender': 'female',
#   'locale': 'en-US',
#   'language': 'English (United States)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-US-MichelleNeural',
#   'name': 'Michelle',
#   'gender': 'female',
#   'locale': 'en-US',
#   'language': 'English (United States)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-US-MonicaNeural',
#   'name': 'Monica',
#   'gender': 'female',
#   'locale': 'en-US',
#   'language': 'English (United States)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-US-RogerNeural',
#   'name': 'Roger',
#   'gender': 'male',
#   'locale': 'en-US',
#   'language': 'English (United States)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-US-RyanMultilingualNeural',
#   'name': 'Ryan Multilingual',
#   'gender': 'male',
#   'locale': 'en-US',
#   'language': 'English (United States)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-US-SteffanNeural',
#   'name': 'Steffan',
#   'gender': 'male',
#   'locale': 'en-US',
#   'language': 'English (United States)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-US-AriaRUS',
#   'name': 'Aria',
#   'gender': 'female',
#   'locale': 'en-US',
#   'language': 'English (United States)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-US-BenjaminRUS',
#   'name': 'Benjamin',
#   'gender': 'male',
#   'locale': 'en-US',
#   'language': 'English (United States)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-US-GuyRUS',
#   'name': 'Guy',
#   'gender': 'male',
#   'locale': 'en-US',
#   'language': 'English (United States)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-US-ZiraRUS',
#   'name': 'Zira',
#   'gender': 'female',
#   'locale': 'en-US',
#   'language': 'English (United States)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-ZA-LeahNeural',
#   'name': 'Leah',
#   'gender': 'female',
#   'locale': 'en-ZA',
#   'language': 'English (South Africa)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'en-ZA-LukeNeural',
#   'name': 'Luke',
#   'gender': 'male',
#   'locale': 'en-ZA',
#   'language': 'English (South Africa)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-AR-ElenaNeural',
#   'name': 'Elena',
#   'gender': 'female',
#   'locale': 'es-AR',
#   'language': 'Spanish (Argentina)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-AR-TomasNeural',
#   'name': 'Tomas',
#   'gender': 'male',
#   'locale': 'es-AR',
#   'language': 'Spanish (Argentina)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-BO-SofiaNeural',
#   'name': 'Sofia',
#   'gender': 'female',
#   'locale': 'es-BO',
#   'language': 'Spanish (Bolivia)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-BO-MarceloNeural',
#   'name': 'Marcelo',
#   'gender': 'male',
#   'locale': 'es-BO',
#   'language': 'Spanish (Bolivia)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-CL-CatalinaNeural',
#   'name': 'Catalina',
#   'gender': 'female',
#   'locale': 'es-CL',
#   'language': 'Spanish (Chile)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-CL-LorenzoNeural',
#   'name': 'Lorenzo',
#   'gender': 'male',
#   'locale': 'es-CL',
#   'language': 'Spanish (Chile)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-CO-SalomeNeural',
#   'name': 'Salome',
#   'gender': 'female',
#   'locale': 'es-CO',
#   'language': 'Spanish (Colombia)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-CO-GonzaloNeural',
#   'name': 'Gonzalo',
#   'gender': 'male',
#   'locale': 'es-CO',
#   'language': 'Spanish (Colombia)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-CR-MariaNeural',
#   'name': 'Maria',
#   'gender': 'female',
#   'locale': 'es-CR',
#   'language': 'Spanish (Costa Rica)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-CR-JuanNeural',
#   'name': 'Juan',
#   'gender': 'male',
#   'locale': 'es-CR',
#   'language': 'Spanish (Costa Rica)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-CU-BelkysNeural',
#   'name': 'Belkys',
#   'gender': 'female',
#   'locale': 'es-CU',
#   'language': 'Spanish (Cuba)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-CU-ManuelNeural',
#   'name': 'Manuel',
#   'gender': 'male',
#   'locale': 'es-CU',
#   'language': 'Spanish (Cuba)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-DO-RamonaNeural',
#   'name': 'Ramona',
#   'gender': 'female',
#   'locale': 'es-DO',
#   'language': 'Spanish (Dominican Republic)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-DO-EmilioNeural',
#   'name': 'Emilio',
#   'gender': 'male',
#   'locale': 'es-DO',
#   'language': 'Spanish (Dominican Republic)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-EC-AndreaNeural',
#   'name': 'Andrea',
#   'gender': 'female',
#   'locale': 'es-EC',
#   'language': 'Spanish (Ecuador)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-EC-LuisNeural',
#   'name': 'Luis',
#   'gender': 'male',
#   'locale': 'es-EC',
#   'language': 'Spanish (Ecuador)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-ES-ElviraNeural',
#   'name': 'Elvira',
#   'gender': 'female',
#   'locale': 'es-ES',
#   'language': 'Spanish (Spain)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-ES-AlvaroNeural',
#   'name': 'Alvaro',
#   'gender': 'male',
#   'locale': 'es-ES',
#   'language': 'Spanish (Spain)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-ES-AbrilNeural',
#   'name': 'Abril',
#   'gender': 'female',
#   'locale': 'es-ES',
#   'language': 'Spanish (Spain)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-ES-ArnauNeural',
#   'name': 'Arnau',
#   'gender': 'male',
#   'locale': 'es-ES',
#   'language': 'Spanish (Spain)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-ES-DarioNeural',
#   'name': 'Dario',
#   'gender': 'male',
#   'locale': 'es-ES',
#   'language': 'Spanish (Spain)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-ES-EliasNeural',
#   'name': 'Elias',
#   'gender': 'male',
#   'locale': 'es-ES',
#   'language': 'Spanish (Spain)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-ES-EstrellaNeural',
#   'name': 'Estrella',
#   'gender': 'female',
#   'locale': 'es-ES',
#   'language': 'Spanish (Spain)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-ES-IreneNeural',
#   'name': 'Irene',
#   'gender': 'female',
#   'locale': 'es-ES',
#   'language': 'Spanish (Spain)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-ES-LaiaNeural',
#   'name': 'Laia',
#   'gender': 'female',
#   'locale': 'es-ES',
#   'language': 'Spanish (Spain)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-ES-LiaNeural',
#   'name': 'Lia',
#   'gender': 'female',
#   'locale': 'es-ES',
#   'language': 'Spanish (Spain)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-ES-NilNeural',
#   'name': 'Nil',
#   'gender': 'male',
#   'locale': 'es-ES',
#   'language': 'Spanish (Spain)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-ES-SaulNeural',
#   'name': 'Saul',
#   'gender': 'male',
#   'locale': 'es-ES',
#   'language': 'Spanish (Spain)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-ES-TeoNeural',
#   'name': 'Teo',
#   'gender': 'male',
#   'locale': 'es-ES',
#   'language': 'Spanish (Spain)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-ES-TrianaNeural',
#   'name': 'Triana',
#   'gender': 'female',
#   'locale': 'es-ES',
#   'language': 'Spanish (Spain)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-ES-VeraNeural',
#   'name': 'Vera',
#   'gender': 'female',
#   'locale': 'es-ES',
#   'language': 'Spanish (Spain)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-ES-HelenaRUS',
#   'name': 'Helena',
#   'gender': 'female',
#   'locale': 'es-ES',
#   'language': 'Spanish (Spain)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-ES-Laura',
#   'name': 'Laura',
#   'gender': 'female',
#   'locale': 'es-ES',
#   'language': 'Spanish (Spain)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-ES-Pablo',
#   'name': 'Pablo',
#   'gender': 'male',
#   'locale': 'es-ES',
#   'language': 'Spanish (Spain)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-GQ-TeresaNeural',
#   'name': 'Teresa',
#   'gender': 'female',
#   'locale': 'es-GQ',
#   'language': 'Spanish (Equatorial Guinea)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-GQ-JavierNeural',
#   'name': 'Javier',
#   'gender': 'male',
#   'locale': 'es-GQ',
#   'language': 'Spanish (Equatorial Guinea)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-GT-MartaNeural',
#   'name': 'Marta',
#   'gender': 'female',
#   'locale': 'es-GT',
#   'language': 'Spanish (Guatemala)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-GT-AndresNeural',
#   'name': 'Andres',
#   'gender': 'male',
#   'locale': 'es-GT',
#   'language': 'Spanish (Guatemala)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-HN-KarlaNeural',
#   'name': 'Karla',
#   'gender': 'female',
#   'locale': 'es-HN',
#   'language': 'Spanish (Honduras)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-HN-CarlosNeural',
#   'name': 'Carlos',
#   'gender': 'male',
#   'locale': 'es-HN',
#   'language': 'Spanish (Honduras)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-MX-DaliaNeural',
#   'name': 'Dalia',
#   'gender': 'female',
#   'locale': 'es-MX',
#   'language': 'Spanish (Mexico)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-MX-JorgeNeural',
#   'name': 'Jorge',
#   'gender': 'male',
#   'locale': 'es-MX',
#   'language': 'Spanish (Mexico)',
#   'access': 'public',
#   'provider': 'microsoft',
#   'styles': ['cheerful', 'chat']},
#  {'id': 'es-MX-BeatrizNeural',
#   'name': 'Beatriz',
#   'gender': 'female',
#   'locale': 'es-MX',
#   'language': 'Spanish (Mexico)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-MX-CandelaNeural',
#   'name': 'Candela',
#   'gender': 'female',
#   'locale': 'es-MX',
#   'language': 'Spanish (Mexico)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-MX-CarlotaNeural',
#   'name': 'Carlota',
#   'gender': 'female',
#   'locale': 'es-MX',
#   'language': 'Spanish (Mexico)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-MX-CecilioNeural',
#   'name': 'Cecilio',
#   'gender': 'male',
#   'locale': 'es-MX',
#   'language': 'Spanish (Mexico)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-MX-GerardoNeural',
#   'name': 'Gerardo',
#   'gender': 'male',
#   'locale': 'es-MX',
#   'language': 'Spanish (Mexico)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-MX-LarissaNeural',
#   'name': 'Larissa',
#   'gender': 'female',
#   'locale': 'es-MX',
#   'language': 'Spanish (Mexico)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-MX-LibertoNeural',
#   'name': 'Liberto',
#   'gender': 'male',
#   'locale': 'es-MX',
#   'language': 'Spanish (Mexico)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-MX-LucianoNeural',
#   'name': 'Luciano',
#   'gender': 'male',
#   'locale': 'es-MX',
#   'language': 'Spanish (Mexico)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-MX-MarinaNeural',
#   'name': 'Marina',
#   'gender': 'female',
#   'locale': 'es-MX',
#   'language': 'Spanish (Mexico)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-MX-NuriaNeural',
#   'name': 'Nuria',
#   'gender': 'female',
#   'locale': 'es-MX',
#   'language': 'Spanish (Mexico)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-MX-PelayoNeural',
#   'name': 'Pelayo',
#   'gender': 'male',
#   'locale': 'es-MX',
#   'language': 'Spanish (Mexico)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-MX-RenataNeural',
#   'name': 'Renata',
#   'gender': 'female',
#   'locale': 'es-MX',
#   'language': 'Spanish (Mexico)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-MX-YagoNeural',
#   'name': 'Yago',
#   'gender': 'male',
#   'locale': 'es-MX',
#   'language': 'Spanish (Mexico)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-MX-HildaRUS',
#   'name': 'Hilda',
#   'gender': 'female',
#   'locale': 'es-MX',
#   'language': 'Spanish (Mexico)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-MX-Raul',
#   'name': 'Raul',
#   'gender': 'male',
#   'locale': 'es-MX',
#   'language': 'Spanish (Mexico)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-NI-YolandaNeural',
#   'name': 'Yolanda',
#   'gender': 'female',
#   'locale': 'es-NI',
#   'language': 'Spanish (Nicaragua)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-NI-FedericoNeural',
#   'name': 'Federico',
#   'gender': 'male',
#   'locale': 'es-NI',
#   'language': 'Spanish (Nicaragua)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-PA-MargaritaNeural',
#   'name': 'Margarita',
#   'gender': 'female',
#   'locale': 'es-PA',
#   'language': 'Spanish (Panama)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-PA-RobertoNeural',
#   'name': 'Roberto',
#   'gender': 'male',
#   'locale': 'es-PA',
#   'language': 'Spanish (Panama)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-PE-CamilaNeural',
#   'name': 'Camila',
#   'gender': 'female',
#   'locale': 'es-PE',
#   'language': 'Spanish (Peru)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-PE-AlexNeural',
#   'name': 'Alex',
#   'gender': 'male',
#   'locale': 'es-PE',
#   'language': 'Spanish (Peru)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-PR-KarinaNeural',
#   'name': 'Karina',
#   'gender': 'female',
#   'locale': 'es-PR',
#   'language': 'Spanish (Puerto Rico)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-PR-VictorNeural',
#   'name': 'Victor',
#   'gender': 'male',
#   'locale': 'es-PR',
#   'language': 'Spanish (Puerto Rico)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-PY-TaniaNeural',
#   'name': 'Tania',
#   'gender': 'female',
#   'locale': 'es-PY',
#   'language': 'Spanish (Paraguay)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-PY-MarioNeural',
#   'name': 'Mario',
#   'gender': 'male',
#   'locale': 'es-PY',
#   'language': 'Spanish (Paraguay)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-SV-LorenaNeural',
#   'name': 'Lorena',
#   'gender': 'female',
#   'locale': 'es-SV',
#   'language': 'Spanish (El Salvador)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-SV-RodrigoNeural',
#   'name': 'Rodrigo',
#   'gender': 'male',
#   'locale': 'es-SV',
#   'language': 'Spanish (El Salvador)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-US-PalomaNeural',
#   'name': 'Paloma',
#   'gender': 'female',
#   'locale': 'es-US',
#   'language': 'Spanish (United States)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-US-AlonsoNeural',
#   'name': 'Alonso',
#   'gender': 'male',
#   'locale': 'es-US',
#   'language': 'Spanish (United States)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-UY-ValentinaNeural',
#   'name': 'Valentina',
#   'gender': 'female',
#   'locale': 'es-UY',
#   'language': 'Spanish (Uruguay)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-UY-MateoNeural',
#   'name': 'Mateo',
#   'gender': 'male',
#   'locale': 'es-UY',
#   'language': 'Spanish (Uruguay)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-VE-PaolaNeural',
#   'name': 'Paola',
#   'gender': 'female',
#   'locale': 'es-VE',
#   'language': 'Spanish (Venezuela)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'es-VE-SebastianNeural',
#   'name': 'Sebastian',
#   'gender': 'male',
#   'locale': 'es-VE',
#   'language': 'Spanish (Venezuela)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'et-EE-AnuNeural',
#   'name': 'Anu',
#   'gender': 'female',
# ...
#   'locale': 'ta-IN',
#   'language': 'Tamil (India)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ta-IN-Valluvar',
#   'name': 'Valluvar',
#   'gender': 'male',
#   'locale': 'ta-IN',
#   'language': 'Tamil (India)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ta-LK-SaranyaNeural',
#   'name': 'Saranya',
#   'gender': 'female',
#   'locale': 'ta-LK',
#   'language': 'Tamil (Sri Lanka)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ta-LK-KumarNeural',
#   'name': 'Kumar',
#   'gender': 'male',
#   'locale': 'ta-LK',
#   'language': 'Tamil (Sri Lanka)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ta-MY-KaniNeural',
#   'name': 'Kani',
#   'gender': 'female',
#   'locale': 'ta-MY',
#   'language': 'Tamil (Malaysia)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ta-MY-SuryaNeural',
#   'name': 'Surya',
#   'gender': 'male',
#   'locale': 'ta-MY',
#   'language': 'Tamil (Malaysia)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ta-SG-VenbaNeural',
#   'name': 'Venba',
#   'gender': 'female',
#   'locale': 'ta-SG',
#   'language': 'Tamil (Singapore)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ta-SG-AnbuNeural',
#   'name': 'Anbu',
#   'gender': 'male',
#   'locale': 'ta-SG',
#   'language': 'Tamil (Singapore)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'te-IN-ShrutiNeural',
#   'name': 'Shruti',
#   'gender': 'female',
#   'locale': 'te-IN',
#   'language': 'Telugu (India)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'te-IN-MohanNeural',
#   'name': 'Mohan',
#   'gender': 'male',
#   'locale': 'te-IN',
#   'language': 'Telugu (India)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'te-IN-Chitra',
#   'name': 'Chitra',
#   'gender': 'female',
#   'locale': 'te-IN',
#   'language': 'Telugu (India)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'th-TH-PremwadeeNeural',
#   'name': 'Premwadee',
#   'gender': 'female',
#   'locale': 'th-TH',
#   'language': 'Thai (Thailand)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'th-TH-NiwatNeural',
#   'name': 'Niwat',
#   'gender': 'male',
#   'locale': 'th-TH',
#   'language': 'Thai (Thailand)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'th-TH-AcharaNeural',
#   'name': 'Achara',
#   'gender': 'female',
#   'locale': 'th-TH',
#   'language': 'Thai (Thailand)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'th-TH-Pattara',
#   'name': 'Pattara',
#   'gender': 'male',
#   'locale': 'th-TH',
#   'language': 'Thai (Thailand)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'tr-TR-EmelNeural',
#   'name': 'Emel',
#   'gender': 'female',
#   'locale': 'tr-TR',
#   'language': 'Turkish (Turkey)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'tr-TR-AhmetNeural',
#   'name': 'Ahmet',
#   'gender': 'male',
#   'locale': 'tr-TR',
#   'language': 'Turkish (Turkey)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'tr-TR-SedaRUS',
#   'name': 'Seda',
#   'gender': 'female',
#   'locale': 'tr-TR',
#   'language': 'Turkish (Turkey)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'uk-UA-PolinaNeural',
#   'name': 'Polina',
#   'gender': 'female',
#   'locale': 'uk-UA',
#   'language': 'Ukrainian (Ukraine)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'uk-UA-OstapNeural',
#   'name': 'Ostap',
#   'gender': 'male',
#   'locale': 'uk-UA',
#   'language': 'Ukrainian (Ukraine)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ur-IN-GulNeural',
#   'name': 'Gul',
#   'gender': 'female',
#   'locale': 'ur-IN',
#   'language': 'Urdu (India)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ur-IN-SalmanNeural',
#   'name': 'Salman',
#   'gender': 'male',
#   'locale': 'ur-IN',
#   'language': 'Urdu (India)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ur-PK-UzmaNeural',
#   'name': 'Uzma',
#   'gender': 'female',
#   'locale': 'ur-PK',
#   'language': 'Urdu (Pakistan)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'ur-PK-AsadNeural',
#   'name': 'Asad',
#   'gender': 'male',
#   'locale': 'ur-PK',
#   'language': 'Urdu (Pakistan)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'uz-UZ-MadinaNeural',
#   'name': 'Madina',
#   'gender': 'female',
#   'locale': 'uz-UZ',
#   'language': 'Uzbek (Latin, Uzbekistan)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'uz-UZ-SardorNeural',
#   'name': 'Sardor',
#   'gender': 'male',
#   'locale': 'uz-UZ',
#   'language': 'Uzbek (Latin, Uzbekistan)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'vi-VN-HoaiMyNeural',
#   'name': 'HoaiMy',
#   'gender': 'female',
#   'locale': 'vi-VN',
#   'language': 'Vietnamese (Vietnam)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'vi-VN-NamMinhNeural',
#   'name': 'NamMinh',
#   'gender': 'male',
#   'locale': 'vi-VN',
#   'language': 'Vietnamese (Vietnam)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'vi-VN-An',
#   'name': 'An',
#   'gender': 'male',
#   'locale': 'vi-VN',
#   'language': 'Vietnamese (Vietnam)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'wuu-CN-XiaotongNeural',
#   'name': 'Xiaotong',
#   'gender': 'female',
#   'locale': 'wuu-CN',
#   'language': 'Chinese (Wu, Simplified)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'wuu-CN-YunzheNeural',
#   'name': 'Yunzhe',
#   'gender': 'male',
#   'locale': 'wuu-CN',
#   'language': 'Chinese (Wu, Simplified)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'yue-CN-XiaoMinNeural',
#   'name': 'XiaoMin',
#   'gender': 'female',
#   'locale': 'yue-CN',
#   'language': 'Chinese (Cantonese, Simplified)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'yue-CN-YunSongNeural',
#   'name': 'YunSong',
#   'gender': 'male',
#   'locale': 'yue-CN',
#   'language': 'Chinese (Cantonese, Simplified)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'zh-CN-XiaoxiaoNeural',
#   'name': 'Xiaoxiao',
#   'gender': 'female',
#   'locale': 'zh-CN',
#   'language': 'Chinese (Mandarin, Simplified)',
#   'access': 'public',
#   'provider': 'microsoft',
#   'styles': ['assistant',
#    'chat',
#    'customerservice',
#    'newscast',
#    'affectionate',
#    'angry',
#    'calm',
#    'cheerful',
#    'disgruntled',
#    'fearful',
#    'gentle',
#    'lyrical',
#    'sad',
#    'serious',
#    'poetry-reading',
#    'friendly',
#    'chat-casual',
#    'whisper',
#    'sorry']},
#  {'id': 'zh-CN-YunxiNeural',
#   'name': 'Yunxi',
#   'gender': 'male',
#   'locale': 'zh-CN',
#   'language': 'Chinese (Mandarin, Simplified)',
#   'access': 'public',
#   'provider': 'microsoft',
#   'styles': ['narration-relaxed',
#    'embarrassed',
#    'fearful',
#    'cheerful',
#    'disgruntled',
#    'serious',
#    'angry',
#    'sad',
#    'depressed',
#    'chat',
#    'assistant',
#    'newscast']},
#  {'id': 'zh-CN-YunjianNeural',
#   'name': 'Yunjian',
#   'gender': 'male',
#   'locale': 'zh-CN',
#   'language': 'Chinese (Mandarin, Simplified)',
#   'access': 'public',
#   'provider': 'microsoft',
#   'styles': ['narration-relaxed',
#    'sports-commentary',
#    'sports-commentary-excited',
#    'angry',
#    'disgruntled',
#    'cheerful',
#    'sad',
#    'serious',
#    'depressed',
#    'documentary-narration']},
#  {'id': 'zh-CN-XiaoyiNeural',
#   'name': 'Xiaoyi',
#   'gender': 'female',
#   'locale': 'zh-CN',
#   'language': 'Chinese (Mandarin, Simplified)',
#   'access': 'public',
#   'provider': 'microsoft',
#   'styles': ['angry',
#    'disgruntled',
#    'affectionate',
#    'cheerful',
#    'fearful',
#    'sad',
#    'embarrassed',
#    'serious',
#    'gentle']},
#  {'id': 'zh-CN-YunyangNeural',
#   'name': 'Yunyang',
#   'gender': 'male',
#   'locale': 'zh-CN',
#   'language': 'Chinese (Mandarin, Simplified)',
#   'access': 'public',
#   'provider': 'microsoft',
#   'styles': ['customerservice', 'narration-professional', 'newscast-casual']},
#  {'id': 'zh-CN-XiaochenNeural',
#   'name': 'Xiaochen',
#   'gender': 'female',
#   'locale': 'zh-CN',
#   'language': 'Chinese (Mandarin, Simplified)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'zh-CN-XiaohanNeural',
#   'name': 'Xiaohan',
#   'gender': 'female',
#   'locale': 'zh-CN',
#   'language': 'Chinese (Mandarin, Simplified)',
#   'access': 'public',
#   'provider': 'microsoft',
#   'styles': ['calm',
#    'fearful',
#    'cheerful',
#    'disgruntled',
#    'serious',
#    'angry',
#    'sad',
#    'gentle',
#    'affectionate',
#    'embarrassed']},
#  {'id': 'zh-CN-XiaomengNeural',
#   'name': 'Xiaomeng',
#   'gender': 'female',
#   'locale': 'zh-CN',
#   'language': 'Chinese (Mandarin, Simplified)',
#   'access': 'public',
#   'provider': 'microsoft',
#   'styles': ['chat']},
#  {'id': 'zh-CN-XiaomoNeural',
#   'name': 'Xiaomo',
#   'gender': 'female',
#   'locale': 'zh-CN',
#   'language': 'Chinese (Mandarin, Simplified)',
#   'access': 'public',
#   'provider': 'microsoft',
#   'styles': ['embarrassed',
#    'calm',
#    'fearful',
#    'cheerful',
#    'disgruntled',
#    'serious',
#    'angry',
#    'sad',
#    'depressed',
#    'affectionate',
#    'gentle',
#    'envious']},
#  {'id': 'zh-CN-XiaoqiuNeural',
#   'name': 'Xiaoqiu',
#   'gender': 'female',
#   'locale': 'zh-CN',
#   'language': 'Chinese (Mandarin, Simplified)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'zh-CN-XiaoruiNeural',
#   'name': 'Xiaorui',
#   'gender': 'female',
#   'locale': 'zh-CN',
#   'language': 'Chinese (Mandarin, Simplified)',
#   'access': 'public',
#   'provider': 'microsoft',
#   'styles': ['calm', 'fearful', 'angry', 'sad']},
#  {'id': 'zh-CN-XiaoshuangNeural',
#   'name': 'Xiaoshuang',
#   'gender': 'female',
#   'locale': 'zh-CN',
#   'language': 'Chinese (Mandarin, Simplified)',
#   'access': 'public',
#   'provider': 'microsoft',
#   'styles': ['chat']},
#  {'id': 'zh-CN-XiaoyanNeural',
#   'name': 'Xiaoyan',
#   'gender': 'female',
#   'locale': 'zh-CN',
#   'language': 'Chinese (Mandarin, Simplified)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'zh-CN-XiaoyouNeural',
#   'name': 'Xiaoyou',
#   'gender': 'female',
#   'locale': 'zh-CN',
#   'language': 'Chinese (Mandarin, Simplified)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'zh-CN-XiaozhenNeural',
#   'name': 'Xiaozhen',
#   'gender': 'female',
#   'locale': 'zh-CN',
#   'language': 'Chinese (Mandarin, Simplified)',
#   'access': 'public',
#   'provider': 'microsoft',
#   'styles': ['angry', 'disgruntled', 'cheerful', 'fearful', 'sad', 'serious']},
#  {'id': 'zh-CN-YunfengNeural',
#   'name': 'Yunfeng',
#   'gender': 'male',
#   'locale': 'zh-CN',
#   'language': 'Chinese (Mandarin, Simplified)',
#   'access': 'public',
#   'provider': 'microsoft',
#   'styles': ['angry',
#    'disgruntled',
#    'cheerful',
#    'fearful',
#    'sad',
#    'serious',
#    'depressed']},
#  {'id': 'zh-CN-YunhaoNeural',
#   'name': 'Yunhao',
#   'gender': 'male',
#   'locale': 'zh-CN',
#   'language': 'Chinese (Mandarin, Simplified)',
#   'access': 'public',
#   'provider': 'microsoft',
#   'styles': ['advertisement-upbeat']},
#  {'id': 'zh-CN-YunxiaNeural',
#   'name': 'Yunxia',
#   'gender': 'male',
#   'locale': 'zh-CN',
#   'language': 'Chinese (Mandarin, Simplified)',
#   'access': 'public',
#   'provider': 'microsoft',
#   'styles': ['calm', 'fearful', 'cheerful', 'angry', 'sad']},
#  {'id': 'zh-CN-YunyeNeural',
#   'name': 'Yunye',
#   'gender': 'male',
#   'locale': 'zh-CN',
#   'language': 'Chinese (Mandarin, Simplified)',
#   'access': 'public',
#   'provider': 'microsoft',
#   'styles': ['embarrassed',
#    'calm',
#    'fearful',
#    'cheerful',
#    'disgruntled',
#    'serious',
#    'angry',
#    'sad']},
#  {'id': 'zh-CN-YunzeNeural',
#   'name': 'Yunze',
#   'gender': 'male',
#   'locale': 'zh-CN',
#   'language': 'Chinese (Mandarin, Simplified)',
#   'access': 'public',
#   'provider': 'microsoft',
#   'styles': ['calm',
#    'fearful',
#    'cheerful',
#    'disgruntled',
#    'serious',
#    'angry',
#    'sad',
#    'depressed',
#    'documentary-narration']},
#  {'id': 'zh-CN-XiaoxuanNeural',
#   'name': 'Xiaoxuan',
#   'gender': 'female',
#   'locale': 'zh-CN',
#   'language': 'Chinese (Mandarin, Simplified)',
#   'access': 'public',
#   'provider': 'microsoft',
#   'styles': ['calm',
#    'fearful',
#    'cheerful',
#    'disgruntled',
#    'serious',
#    'angry',
#    'gentle',
#    'depressed']},
#  {'id': 'zh-CN-HuihuiRUS',
#   'name': 'Huihui',
#   'gender': 'female',
#   'locale': 'zh-CN',
#   'language': 'Chinese (Mandarin, Simplified)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'zh-CN-Kangkang',
#   'name': 'Kangkang',
#   'gender': 'male',
#   'locale': 'zh-CN',
#   'language': 'Chinese (Mandarin, Simplified)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'zh-CN-Yaoyao',
#   'name': 'Yaoyao',
#   'gender': 'female',
#   'locale': 'zh-CN',
#   'language': 'Chinese (Mandarin, Simplified)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'zh-CN-henan-YundengNeural',
#   'name': 'Yundeng',
#   'gender': 'male',
#   'locale': 'zh-CN-henan',
#   'language': 'Chinese (Zhongyuan Mandarin Henan, Simplified)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'zh-CN-liaoning-XiaobeiNeural',
#   'name': 'Xiaobei',
#   'gender': 'female',
#   'locale': 'zh-CN-liaoning',
#   'language': 'Chinese (Northeastern Mandarin, Simplified)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'zh-CN-shaanxi-XiaoniNeural',
#   'name': 'Xiaoni',
#   'gender': 'female',
#   'locale': 'zh-CN-shaanxi',
#   'language': 'Chinese (Zhongyuan Mandarin Shaanxi, Simplified)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'zh-CN-shandong-YunxiangNeural',
#   'name': 'Yunxiang',
#   'gender': 'male',
#   'locale': 'zh-CN-shandong',
#   'language': 'Chinese (Jilu Mandarin, Simplified)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'zh-CN-sichuan-YunxiNeural',
#   'name': 'YunxiSichuan',
#   'gender': 'male',
#   'locale': 'zh-CN-sichuan',
#   'language': 'Chinese (Southwestern Mandarin, Simplified)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'zh-HK-HiuMaanNeural',
#   'name': 'HiuMaan',
#   'gender': 'female',
#   'locale': 'zh-HK',
#   'language': 'Chinese (Cantonese, Traditional)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'zh-HK-WanLungNeural',
#   'name': 'WanLung',
#   'gender': 'male',
#   'locale': 'zh-HK',
#   'language': 'Chinese (Cantonese, Traditional)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'zh-HK-HiuGaaiNeural',
#   'name': 'HiuGaai',
#   'gender': 'female',
#   'locale': 'zh-HK',
#   'language': 'Chinese (Cantonese, Traditional)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'zh-HK-Danny',
#   'name': 'Danny',
#   'gender': 'male',
#   'locale': 'zh-HK',
#   'language': 'Chinese (Cantonese, Traditional)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'zh-HK-TracyRUS',
#   'name': 'Tracy',
#   'gender': 'female',
#   'locale': 'zh-HK',
#   'language': 'Chinese (Cantonese, Traditional)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'zh-TW-HsiaoChenNeural',
#   'name': 'HsiaoChen',
#   'gender': 'female',
#   'locale': 'zh-TW',
#   'language': 'Chinese (Taiwanese Mandarin, Traditional)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'zh-TW-YunJheNeural',
#   'name': 'YunJhe',
#   'gender': 'male',
#   'locale': 'zh-TW',
#   'language': 'Chinese (Taiwanese Mandarin, Traditional)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'zh-TW-HsiaoYuNeural',
#   'name': 'HsiaoYu',
#   'gender': 'female',
#   'locale': 'zh-TW',
#   'language': 'Chinese (Taiwanese Mandarin, Traditional)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'zh-TW-HanHanRUS',
#   'name': 'HanHan',
#   'gender': 'female',
#   'locale': 'zh-TW',
#   'language': 'Chinese (Taiwanese Mandarin, Traditional)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'zh-TW-Yating',
#   'name': 'Yating',
#   'gender': 'female',
#   'locale': 'zh-TW',
#   'language': 'Chinese (Taiwanese Mandarin, Traditional)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'zh-TW-Zhiwei',
#   'name': 'Zhiwei',
#   'gender': 'male',
#   'locale': 'zh-TW',
#   'language': 'Chinese (Taiwanese Mandarin, Traditional)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'zu-ZA-ThandoNeural',
#   'name': 'Thando',
#   'gender': 'female',
#   'locale': 'zu-ZA',
#   'language': 'Zulu (South Africa)',
#   'access': 'public',
#   'provider': 'microsoft'},
#  {'id': 'zu-ZA-ThembaNeural',
#   'name': 'Themba',
#   'gender': 'male',
#   'locale': 'zu-ZA',
#   'language': 'Zulu (South Africa)',
#   'access': 'public',
#   'provider': 'microsoft'}]

# %% [markdown]
# ###Creat clip

# %%
url = "https://api.d-id.com/clips"

D_iD_API_KEY=os.getenv("D_iD_API_KEY")

payload = {
    "script": {
        "type": "text",

        "provider": {
            "type": "microsoft",
            "voice_id": "en-US-BrianNeural"
        },
        "ssml": "false",
        "input":"hi zeinab, I am AI assitant."
    },

    "config": { "result_format": "mp4" },
    "presenter_config": { "crop": { "type": "wide" } },
    "background": { "color": "false" },
    "presenter_id": "matt-9C51DD6lgH"
}

headers = {
    "accept": "application/json",
    "content-type": "application/json",
    "authorization": D_iD_API_KEY

    }
response = requests.post(url, json=payload, headers=headers)

response.status_code
# Out:
# 201

# %%
response.json()
# Out:
# {'id': 'clp_6TGnJqQVhWxtZY2F7ryZr',
#  'created_at': '2024-03-19T00:57:47.673Z',
#  'object': 'clip',
#  'status': 'created'}

# %% [markdown]
# ###Get clip

# %%
url = f"https://api.d-id.com/clips/{response.json()['id']}"

D_iD_API_KEY=os.getenv("D_iD_API_KEY")

headers = {
    "accept": "application/json",
     "authorization": D_iD_API_KEY
}

response = requests.get(url, headers=headers)

# %%
response.json()
# Out:
# {'script': {'length': 28,
#   'ssml': False,
#   'subtitles': False,
#   'type': 'text',
#   'provider': {'type': 'microsoft', 'voice_id': 'en-US-BrianNeural'}},
#  'metadata': {'num_frames': 52,
#   'processing_fps': 0.8686732584600464,
#   'resolution': [1080, 1080],
#   'size_kib': 3361.3662109375},
#  'audio_url': 'https://d-id-clips-prod.s3.us-west-2.amazonaws.com/auth0%7C65f56bc8c0912636c1df4d2b/clp_6TGnJqQVhWxtZY2F7ryZr/microsoft.wav?AWSAccessKeyId=AKIA5CUMPJBIJ7CPKJNP&Expires=1710896267&Signature=glUM9%2B9yXOMJyzCwq3Uvb0vzTus%3D',
#  'created_at': '2024-03-19T00:57:47.673Z',
#  'config': {'logo': {'url': 'https://d-id-user-logos-prod.s3.us-west-2.amazonaws.com/default/worker/did-watermark-2023.png',
#    'position': [0, 0]},
#   'result_format': '.mp4',
#   'fluent': False,
#   'motion_factor_kp': [1, 0.75]},
#  'source_url': 'https://clips-presenters.d-id.com/matt/9C51DD6lgH/_4VZQb0Ca5/thumbnail.png',
#  'created_by': 'auth0|65f56bc8c0912636c1df4d2b',
#  'status': 'done',
#  'modified_at': '2024-03-19T00:58:48.100Z',
#  'completed_at': '2024-03-19T00:58:48.009',
#  'background': {'color': False},
#  'presenter_id': 'matt-9C51DD6lgH',
#  'subtitles': False,
#  'id': 'clp_6TGnJqQVhWxtZY2F7ryZr',
#  'duration': 3,
#  'presenter_config': {'crop': {'type': 'wide'}},
#  'started_at': '2024-03-19T00:57:47.717',
#  'result_url': 'https://d-id-clips-prod.s3.us-west-2.amazonaws.com/auth0%7C65f56bc8c0912636c1df4d2b/clp_6TGnJqQVhWxtZY2F7ryZr/matt-9C51DD6lgH.mp4?AWSAccessKeyId=AKIA5CUMPJBIJ7CPKJNP&Expires=1710896328&Signature=vzoFTFZvWvAYkfAf2cqjvFPUTKU%3D',
#  'user': {'features': ['stitch', 'clips:write', None],
#   'stripe_plan_group': 'deid-trial',
#   'authorizer': 'basic',
#   'owner_id': 'auth0|65f56bc8c0912636c1df4d2b',
#   'id': 'auth0|65f56bc8c0912636c1df4d2b',
#   'plan': 'deid-trial',
#   'email': 'zinap.mostafavi1378@gmail.com'},
#  'owner_id': 'auth0|65f56bc8c0912636c1df4d2b'}

# %% [markdown]
# #**Plantnet**🍀

# %%
url = "https://my-api.plantnet.org/v2/identify/all"

PlantNet_API_KEY=os.getenv("PlantNet_API_KEY")

headers = {

}
payload = {
    "api-key":PlantNet_API_KEY
}
files={
    "images" : open("/assets/image.jpg","rb")
}
response = requests.post(url, params=payload, headers=headers, files=files)
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'query': {'project': 'all',
#   'images': ['c16efe4d4139db2620dc2fe23e31de17'],
#   'organs': ['auto'],
#   'includeRelatedImages': False,
#   'noReject': False},
#  'language': 'en',
#  'preferedReferential': 'k-world-flora',
#  'bestMatch': 'Monstera deliciosa Liebm.',
#  'results': [{'score': 0.50075,
#    'species': {'scientificNameWithoutAuthor': 'Monstera deliciosa',
#     'scientificNameAuthorship': 'Liebm.',
#     'genus': {'scientificNameWithoutAuthor': 'Monstera',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Monstera'},
#     'family': {'scientificNameWithoutAuthor': 'Araceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Araceae'},
#     'commonNames': ['Monstera', 'Swiss-cheese-plant', 'برگ انجیری'],
#     'scientificName': 'Monstera deliciosa Liebm.'},
#    'gbif': {'id': '2868241'},
#    'powo': {'id': '87478-1'}},
#   {'score': 0.12026,
#    'species': {'scientificNameWithoutAuthor': 'Rhaphidophora tetrasperma',
#     'scientificNameAuthorship': 'Hook.f.',
#     'genus': {'scientificNameWithoutAuthor': 'Rhaphidophora',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Rhaphidophora'},
#     'family': {'scientificNameWithoutAuthor': 'Araceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Araceae'},
#     'commonNames': ['Mini Monstera',
#      'Swiss Cheese plant',
#      'Monstera deliciosa'],
#     'scientificName': 'Rhaphidophora tetrasperma Hook.f.'},
#    'gbif': {'id': '5329745'},
#    'powo': {'id': '88594-1'}},
#   {'score': 0.02409,
#    'species': {'scientificNameWithoutAuthor': 'Monstera minima',
#     'scientificNameAuthorship': 'Madison',
#     'genus': {'scientificNameWithoutAuthor': 'Monstera',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Monstera'},
#     'family': {'scientificNameWithoutAuthor': 'Araceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Araceae'},
#     'commonNames': ['Mini monstera', 'مانسترا', 'برگ انجیری'],
#     'scientificName': 'Monstera minima Madison'},
#    'gbif': {'id': '2868240'},
#    'powo': {'id': '163942-2'}},
#   {'score': 0.0207,
#    'species': {'scientificNameWithoutAuthor': 'Monstera adansonii',
#     'scientificNameAuthorship': 'Schott',
#     'genus': {'scientificNameWithoutAuthor': 'Monstera',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Monstera'},
#     'family': {'scientificNameWithoutAuthor': 'Araceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Araceae'},
#     'commonNames': ['Swiss-cheese-plant', 'Monkey mask', 'Tarovine'],
#     'scientificName': 'Monstera adansonii Schott'},
#    'gbif': {'id': '2868136'},
#    'powo': {'id': '87464-1'}},
#   {'score': 0.00471,
#    'species': {'scientificNameWithoutAuthor': 'Oxalis lasiopetala',
#     'scientificNameAuthorship': 'Zucc.',
#     'genus': {'scientificNameWithoutAuthor': 'Oxalis',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Oxalis'},
#     'family': {'scientificNameWithoutAuthor': 'Oxalidaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Oxalidaceae'},
#     'commonNames': [],
#     'scientificName': 'Oxalis lasiopetala Zucc.'},
#    'gbif': {'id': '7318248'},
#    'powo': {'id': '375048-1'}},
#   {'score': 0.00441,
#    'species': {'scientificNameWithoutAuthor': 'Rhaphidophora pertusa',
#     'scientificNameAuthorship': '(Roxb.) Schott',
#     'genus': {'scientificNameWithoutAuthor': 'Rhaphidophora',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Rhaphidophora'},
#     'family': {'scientificNameWithoutAuthor': 'Araceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Araceae'},
#     'commonNames': [],
#     'scientificName': 'Rhaphidophora pertusa (Roxb.) Schott'},
#    'gbif': {'id': '5329763'},
#    'powo': {'id': '88567-1'}},
#   {'score': 0.00393,
#    'species': {'scientificNameWithoutAuthor': 'Thaumatophyllum bipinnatifidum',
#     'scientificNameAuthorship': '(Schott ex Endl.) Sakur., Calazans & Mayo',
#     'genus': {'scientificNameWithoutAuthor': 'Thaumatophyllum',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Thaumatophyllum'},
#     'family': {'scientificNameWithoutAuthor': 'Araceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Araceae'},
#     'commonNames': ['Split leaved philodendron'],
#     'scientificName': 'Thaumatophyllum bipinnatifidum (Schott ex Endl.) Sakur., Calazans & Mayo'},
#    'gbif': {'id': '9689104'},
#    'powo': {'id': '77178497-1'}},
#   {'score': 0.00388,
#    'species': {'scientificNameWithoutAuthor': 'Philodendron gloriosum',
#     'scientificNameAuthorship': 'André',
#     'genus': {'scientificNameWithoutAuthor': 'Philodendron',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Philodendron'},
#     'family': {'scientificNameWithoutAuthor': 'Araceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Araceae'},
#     'commonNames': ['Leri'],
#     'scientificName': 'Philodendron gloriosum André'},
#    'gbif': {'id': '2870786'},
#    'powo': {'id': '87777-1'},
#    'iucn': {'id': '129739546', 'category': 'VU'}},
#   {'score': 0.00383,
#    'species': {'scientificNameWithoutAuthor': 'Philodendron mayoi',
#     'scientificNameAuthorship': 'E.G.Gonç.',
#     'genus': {'scientificNameWithoutAuthor': 'Philodendron',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Philodendron'},
#     'family': {'scientificNameWithoutAuthor': 'Araceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Araceae'},
#     'commonNames': ['Split Leaf philodendron'],
#     'scientificName': 'Philodendron mayoi E.G.Gonç.'},
#    'gbif': {'id': '2871293'},
#    'powo': {'id': '319899-2'}},
#   {'score': 0.00368,
#    'species': {'scientificNameWithoutAuthor': 'Syzygium phillyreifolium',
#     'scientificNameAuthorship': '(Baker) Labat & Schatz',
#     'genus': {'scientificNameWithoutAuthor': 'Syzygium',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Syzygium'},
#     'family': {'scientificNameWithoutAuthor': 'Myrtaceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Myrtaceae'},
#     'commonNames': ['Aggregate eugenia',
#      'Cherry of the Rio Grande',
#      'Cherry of rio grande'],
#     'scientificName': 'Syzygium phillyreifolium (Baker) Labat & Schatz'},
#    'gbif': {'id': '3182742'},
#    'powo': {'id': '20006861-1'},
#    'iucn': {'id': '137698916', 'category': 'LC'}},
#   {'score': 0.00342,
#    'species': {'scientificNameWithoutAuthor': 'Philodendron maximum',
#     'scientificNameAuthorship': 'K.Krause',
#     'genus': {'scientificNameWithoutAuthor': 'Philodendron',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Philodendron'},
#     'family': {'scientificNameWithoutAuthor': 'Araceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Araceae'},
#     'commonNames': [],
#     'scientificName': 'Philodendron maximum K.Krause'},
#    'gbif': {'id': '2871298'},
#    'powo': {'id': '193105-2'}},
#   {'score': 0.0034,
#    'species': {'scientificNameWithoutAuthor': 'Monstera obliqua',
#     'scientificNameAuthorship': 'Miq.',
#     'genus': {'scientificNameWithoutAuthor': 'Monstera',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Monstera'},
#     'family': {'scientificNameWithoutAuthor': 'Araceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Araceae'},
#     'commonNames': ['Swiss cheese plant', 'Broken  Heart Plant'],
#     'scientificName': 'Monstera obliqua Miq.'},
#    'gbif': {'id': '2868185'},
#    'powo': {'id': '87525-1'}},
#   {'score': 0.00322,
#    'species': {'scientificNameWithoutAuthor': 'Philodendron squamiferum',
#     'scientificNameAuthorship': 'Poepp.',
#     'genus': {'scientificNameWithoutAuthor': 'Philodendron',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Philodendron'},
#     'family': {'scientificNameWithoutAuthor': 'Araceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Araceae'},
#     'commonNames': ['Brezilian Chemagadda'],
#     'scientificName': 'Philodendron squamiferum Poepp.'},
#    'gbif': {'id': '2870698'},
#    'powo': {'id': '88023-1'}},
#   {'score': 0.00304,
#    'species': {'scientificNameWithoutAuthor': 'Monstera acuminata',
#     'scientificNameAuthorship': 'K.Koch',
#     'genus': {'scientificNameWithoutAuthor': 'Monstera',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Monstera'},
#     'family': {'scientificNameWithoutAuthor': 'Araceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Araceae'},
#     'commonNames': [],
#     'scientificName': 'Monstera acuminata K.Koch'},
#    'gbif': {'id': '2868214'},
#    'powo': {'id': '87463-1'}},
#   {'score': 0.00235,
#    'species': {'scientificNameWithoutAuthor': 'Epipremnum pinnatum',
#     'scientificNameAuthorship': '(L.) Engl.',
#     'genus': {'scientificNameWithoutAuthor': 'Epipremnum',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Epipremnum'},
#     'family': {'scientificNameWithoutAuthor': 'Araceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Araceae'},
#     'commonNames': ['Pothos', "Devil's-ivy", 'Golden pothos'],
#     'scientificName': 'Epipremnum pinnatum (L.) Engl.'},
#    'gbif': {'id': '2868272'},
#    'powo': {'id': '87046-1'}},
#   {'score': 0.00226,
#    'species': {'scientificNameWithoutAuthor': 'Philodendron giganteum',
#     'scientificNameAuthorship': 'Schott',
#     'genus': {'scientificNameWithoutAuthor': 'Philodendron',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Philodendron'},
#     'family': {'scientificNameWithoutAuthor': 'Araceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Araceae'},
#     'commonNames': ['Giant philodendron', 'Chinabush', 'Elephant Ear'],
#     'scientificName': 'Philodendron giganteum Schott'},
#    'gbif': {'id': '2870862'},
#    'powo': {'id': '87774-1'}},
#   {'score': 0.00211,
#    'species': {'scientificNameWithoutAuthor': 'Monstera pittieri',
#     'scientificNameAuthorship': 'Engl.',
#     'genus': {'scientificNameWithoutAuthor': 'Monstera',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Monstera'},
#     'family': {'scientificNameWithoutAuthor': 'Araceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Araceae'},
#     'commonNames': [],
#     'scientificName': 'Monstera pittieri Engl.'},
#    'gbif': {'id': '2868183'},
#    'powo': {'id': '163956-2'}},
#   {'score': 0.00197,
#    'species': {'scientificNameWithoutAuthor': 'Monstera lechleriana',
#     'scientificNameAuthorship': 'Schott',
#     'genus': {'scientificNameWithoutAuthor': 'Monstera',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Monstera'},
#     'family': {'scientificNameWithoutAuthor': 'Araceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Araceae'},
#     'commonNames': ['Split leaf'],
#     'scientificName': 'Monstera lechleriana Schott'},
#    'gbif': {'id': '2868201'},
#    'powo': {'id': '87509-1'}},
#   {'score': 0.00197,
#    'species': {'scientificNameWithoutAuthor': 'Monstera dubia',
#     'scientificNameAuthorship': '(Kunth) Engl. & K.Krause',
#     'genus': {'scientificNameWithoutAuthor': 'Monstera',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Monstera'},
#     'family': {'scientificNameWithoutAuthor': 'Araceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Araceae'},
#     'commonNames': ['Wall painting creeper'],
#     'scientificName': 'Monstera dubia (Kunth) Engl. & K.Krause'},
#    'gbif': {'id': '2868179'},
#    'powo': {'id': '163921-2'}},
#   {'score': 0.0018,
#    'species': {'scientificNameWithoutAuthor': 'Rhaphidophora decursiva',
#     'scientificNameAuthorship': '(Roxb.) Schott',
#     'genus': {'scientificNameWithoutAuthor': 'Rhaphidophora',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Rhaphidophora'},
#     'family': {'scientificNameWithoutAuthor': 'Araceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Araceae'},
#     'commonNames': ['Dragon tail', 'Schott plant'],
#     'scientificName': 'Rhaphidophora decursiva (Roxb.) Schott'},
#    'gbif': {'id': '5329707'},
#    'powo': {'id': '88471-1'}},
#   {'score': 0.00144,
#    'species': {'scientificNameWithoutAuthor': 'Monstera punctulata',
#     'scientificNameAuthorship': '(Schott) Schott ex Engl.',
#     'genus': {'scientificNameWithoutAuthor': 'Monstera',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Monstera'},
#     'family': {'scientificNameWithoutAuthor': 'Araceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Araceae'},
#     'commonNames': [],
#     'scientificName': 'Monstera punctulata (Schott) Schott ex Engl.'},
#    'gbif': {'id': '2868198'},
#    'powo': {'id': '87541-1'}},
#   {'score': 0.00134,
#    'species': {'scientificNameWithoutAuthor': 'Philodendron radiatum',
#     'scientificNameAuthorship': 'Schott',
#     'genus': {'scientificNameWithoutAuthor': 'Philodendron',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Philodendron'},
#     'family': {'scientificNameWithoutAuthor': 'Araceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Araceae'},
#     'commonNames': ['Split leaf climber'],
#     'scientificName': 'Philodendron radiatum Schott'},
#    'gbif': {'id': '2870769'},
#    'powo': {'id': '314452-2'}},
#   {'score': 0.00113,
#    'species': {'scientificNameWithoutAuthor': 'Monstera spruceana',
#     'scientificNameAuthorship': '(Schott) Engl.',
#     'genus': {'scientificNameWithoutAuthor': 'Monstera',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Monstera'},
#     'family': {'scientificNameWithoutAuthor': 'Araceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Araceae'},
#     'commonNames': [],
#     'scientificName': 'Monstera spruceana (Schott) Engl.'},
#    'gbif': {'id': '2868126'},
#    'powo': {'id': '87547-1'}},
#   {'score': 0.0011,
#    'species': {'scientificNameWithoutAuthor': 'Thaumatophyllum xanadu',
#     'scientificNameAuthorship': '(Croat, J.Boos & Mayo) Sakur., Calazans & Mayo',
#     'genus': {'scientificNameWithoutAuthor': 'Thaumatophyllum',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Thaumatophyllum'},
#     'family': {'scientificNameWithoutAuthor': 'Araceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Araceae'},
#     'commonNames': ['Selloum Philodendron Plant', 'Philodendron Atom', 'Obi'],
#     'scientificName': 'Thaumatophyllum xanadu (Croat, J.Boos & Mayo) Sakur., Calazans & Mayo'},
#    'gbif': {'id': '9669385'},
#    'powo': {'id': '77178495-1'}},
#   {'score': 0.00103,
#    'species': {'scientificNameWithoutAuthor': 'Rhaphidophora crassicaulis',
#     'scientificNameAuthorship': 'Engl. & K.Krause',
#     'genus': {'scientificNameWithoutAuthor': 'Rhaphidophora',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Rhaphidophora'},
#     'family': {'scientificNameWithoutAuthor': 'Araceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Araceae'},
#     'commonNames': ['Raph Split Leaves'],
#     'scientificName': 'Rhaphidophora crassicaulis Engl. & K.Krause'},
#    'gbif': {'id': '5329790'},
#    'powo': {'id': '88465-1'}},
#   {'score': 0.00101,
#    'species': {'scientificNameWithoutAuthor': 'Thaumatophyllum brasiliense',
#     'scientificNameAuthorship': '(Engl.) Sakur., Calazans & Mayo',
#     'genus': {'scientificNameWithoutAuthor': 'Thaumatophyllum',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Thaumatophyllum'},
#     'family': {'scientificNameWithoutAuthor': 'Araceae',
#      'scientificNameAuthorship': '',
#      'scientificName': 'Araceae'},
#     'commonNames': ['Brazilian Heartleaf Philodendrin'],
#     'scientificName': 'Thaumatophyllum brasiliense (Engl.) Sakur., Calazans & Mayo'},
#    'gbif': {'id': '9731469'},
#    'powo': {'id': '77178484-1'}}],
#  'version': '2024-02-22 (7.1)'}
